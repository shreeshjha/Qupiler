# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '2.0.0'

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
inv0 = QuantumRegister(4, 'inv0')
c0 = QuantumRegister(5, 'c0')
t00 = QuantumRegister(1, 't00')
t10 = QuantumRegister(1, 't10')
t20 = QuantumRegister(1, 't20')
t30 = QuantumRegister(1, 't30')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, inv0, c0, t00, t10, t20, t30, t0)

# Function: main
initialize_register(qc, q0, 5, 4)
initialize_register(qc, q1, 1, 4)
qc.cx(q1[0], inv0[0])
qc.x(inv0[0])
qc.cx(q1[1], inv0[1])
qc.x(inv0[1])
qc.cx(q1[2], inv0[2])
qc.x(inv0[2])
qc.cx(q1[3], inv0[3])
qc.x(inv0[3])
qc.x(c0[0])
qc.cx(q0[0], q3[3])
qc.cx(inv0[0], q3[3])
qc.cx(c0[0], q3[3])
qc.ccx(q0[0], inv0[0], c0[1])
qc.ccx(q3[3], c0[0], t00[0])
qc.cx(t00[0], c0[1])
qc.cx(q0[1], q3[2])
qc.cx(inv0[1], q3[2])
qc.cx(c0[1], q3[2])
qc.ccx(q0[1], inv0[1], c0[2])
qc.ccx(q3[2], c0[1], t10[0])
qc.cx(t10[0], c0[2])
qc.cx(q0[2], q3[1])
qc.cx(inv0[2], q3[1])
qc.cx(c0[2], q3[1])
qc.ccx(q0[2], inv0[2], c0[3])
qc.ccx(q3[1], c0[2], t20[0])
qc.cx(t20[0], c0[3])
qc.cx(q0[3], q3[0])
qc.cx(inv0[3], q3[0])
qc.cx(c0[3], q3[0])
qc.ccx(q0[3], inv0[3], c0[4])
qc.ccx(q3[0], c0[3], t30[0])
qc.cx(t30[0], c0[4])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='automatic')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")

print("Circuit diagram:")
print(qc)

# You can uncomment the following line to show the circuit diagram graphically
# qc.draw(output='mpl').show()

# Run the circuit on the simulator
# simulator = AerSimulator()
# job = simulator.run(qc, shots=1024)
# result = job.result()
# counts = result.get_counts()
# print("\nMeasurement results:", counts)

# print('Measurement result:', t0)


# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization
# qc.decompose()
# print(qc)
# Out:
# Measurement result: ClassicalRegister(4, 't0')
#
# Measurement results: {'0100': 1024}
# Circuit output: 4 (binary: 0100)
# Circuit diagram:
#         ┌───┐                                                                 »
#   q0_0: ┤ X ├───────────────────────────■─────────────────────────────────────»
#         └───┘                           │                                     »
#   q0_1: ─────────────────■──────────────┼───────────────────■─────────────────»
#         ┌───┐            │              │                   │                 »
#   q0_2: ┤ X ├────────────┼──────────────┼────■──────────────┼────■────────────»
#         └───┘            │              │    │              │    │            »
#   q0_3: ─────────────────┼────■─────────┼────┼──────────────┼────┼────■───────»
#         ┌───┐            │    │         │    │              │    │    │       »
#   q1_0: ┤ X ├────────────┼────┼────■────┼────┼──────────────┼────┼────┼───────»
# ...

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
c0 = QuantumRegister(5, 'c0')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, c0, t0)

# Function: main
initialize_register(qc, q0, 7, 4)
initialize_register(qc, q1, 5, 4)
qc.cx(q0[0], q3[0])
qc.cx(q1[0], q3[0])
qc.ccx(q0[0], q1[0], c0[1])
qc.cx(q0[1], q3[1])
qc.cx(q1[1], q3[1])
qc.ccx(q0[1], q1[1], c0[2])
qc.ccx(q3[1], c0[1], c0[2])
qc.cx(c0[1], q3[1])
qc.cx(q0[2], q3[2])
qc.cx(q1[2], q3[2])
qc.ccx(q0[2], q1[2], c0[3])
qc.ccx(q3[2], c0[2], c0[3])
qc.cx(c0[2], q3[2])
qc.cx(q0[3], q3[3])
qc.cx(q1[3], q3[3])
qc.ccx(q0[3], q1[3], c0[4])
qc.ccx(q3[3], c0[3], c0[4])
qc.cx(c0[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='automatic')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")
    
print("Circuit diagram:")
print(qc)
# Out:
# Measurement result: ClassicalRegister(4, 't0')
#
# Measurement results: {'1100': 1024}
# Circuit output: 12 (binary: 1100)
# Circuit diagram:
#       ┌───┐                                                                    »
# q0_0: ┤ X ├───────■───────────────────────────────────────■────────────────────»
#       ├───┤       │                                       │                    »
# q0_1: ┤ X ├───────┼────■──────────────────────────────────┼────■───────────────»
#       ├───┤       │    │                                  │    │               »
# q0_2: ┤ X ├───────┼────┼────■─────────────────────────────┼────┼────■──────────»
#       └───┘       │    │    │                             │    │    │          »
# q0_3: ───────■────┼────┼────┼────────────────────────■────┼────┼────┼──────────»
#       ┌───┐  │    │    │    │                        │    │    │    │          »
# q1_0: ┤ X ├──┼────┼────┼────┼─────────■──────────────┼────■────┼────┼──────────»
# ...

# %%
# Out:
# Measurement result: ClassicalRegister(4, 't0')
#
# Measurement results: {'0100': 1024}
# Circuit output: 4 (binary: 0100)
# Circuit diagram:
#         ┌───┐                                                                 »
#   q0_0: ┤ X ├──────────────────────■───────────────────────────────────────■──»
#         ├───┤                      │                                       │  »
#   q0_1: ┤ X ├──────────────────────┼────■──────────────────────────────────┼──»
#         ├───┤                      │    │                                  │  »
#   q0_2: ┤ X ├──────────────────────┼────┼────■──────────────■──────────────┼──»
#         └───┘                      │    │    │              │              │  »
#   q0_3: ────────────■──────────────┼────┼────┼──────────────┼────■─────────┼──»
#                     │              │    │    │              │    │         │  »
#   q1_0: ────────────┼──────────────┼────┼────┼──────────────┼────┼─────────┼──»
# ...

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
acc0 = QuantumRegister(8, 'acc0')
ctl0 = QuantumRegister(1, 'ctl0')
ctl1 = QuantumRegister(1, 'ctl1')
ctl2 = QuantumRegister(1, 'ctl2')
ctl3 = QuantumRegister(1, 'ctl3')
ctl4 = QuantumRegister(1, 'ctl4')
ctl5 = QuantumRegister(1, 'ctl5')
ctl6 = QuantumRegister(1, 'ctl6')
ctl7 = QuantumRegister(1, 'ctl7')
ctl8 = QuantumRegister(1, 'ctl8')
ctl9 = QuantumRegister(1, 'ctl9')
ctl10 = QuantumRegister(1, 'ctl10')
ctl11 = QuantumRegister(1, 'ctl11')
ctl12 = QuantumRegister(1, 'ctl12')
ctl13 = QuantumRegister(1, 'ctl13')
ctl14 = QuantumRegister(1, 'ctl14')
ctl15 = QuantumRegister(1, 'ctl15')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, acc0, ctl0, ctl1, ctl2, ctl3, ctl4, ctl5, ctl6, ctl7, ctl8, ctl9, ctl10, ctl11, ctl12, ctl13, ctl14, ctl15, t0)

# Function: main
initialize_register(qc, q0, 2, 4)
initialize_register(qc, q1, 4, 4)
qc.ccx(q1[0], q0[0], ctl0[0])
qc.cx(ctl0[0], acc0[0])
qc.ccx(q1[0], q0[1], ctl1[0])
qc.cx(ctl1[0], acc0[1])
qc.ccx(q1[0], q0[2], ctl2[0])
qc.cx(ctl2[0], acc0[2])
qc.ccx(q1[0], q0[3], ctl3[0])
qc.cx(ctl3[0], acc0[3])
qc.ccx(q1[1], q0[0], ctl4[0])
qc.cx(ctl4[0], acc0[1])
qc.ccx(q1[1], q0[1], ctl5[0])
qc.cx(ctl5[0], acc0[2])
qc.ccx(q1[1], q0[2], ctl6[0])
qc.cx(ctl6[0], acc0[3])
qc.ccx(q1[1], q0[3], ctl7[0])
qc.cx(ctl7[0], acc0[4])
qc.ccx(q1[2], q0[0], ctl8[0])
qc.cx(ctl8[0], acc0[2])
qc.ccx(q1[2], q0[1], ctl9[0])
qc.cx(ctl9[0], acc0[3])
qc.ccx(q1[2], q0[2], ctl10[0])
qc.cx(ctl10[0], acc0[4])
qc.ccx(q1[2], q0[3], ctl11[0])
qc.cx(ctl11[0], acc0[5])
qc.ccx(q1[3], q0[0], ctl12[0])
qc.cx(ctl12[0], acc0[3])
qc.ccx(q1[3], q0[1], ctl13[0])
qc.cx(ctl13[0], acc0[4])
qc.ccx(q1[3], q0[2], ctl14[0])
qc.cx(ctl14[0], acc0[5])
qc.ccx(q1[3], q0[3], ctl15[0])
qc.cx(ctl15[0], acc0[6])
qc.cx(acc0[0], q3[0])
qc.cx(acc0[1], q3[1])
qc.cx(acc0[2], q3[2])
qc.cx(acc0[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")

print(qc)
# Out:
# Measurement result: ClassicalRegister(4, 't0')
#
# Measurement results: {'1000': 1024}
# Circuit output: 8 (binary: 1000)
#                                                                               »
#   q0_0: ───────■──────────────■───────────────────■───────────────────────────»
#         ┌───┐  │              │                   │                           »
#   q0_1: ┤ X ├──┼─────────■────┼──────────────■────┼────────────────────────■──»
#         └───┘  │         │    │              │    │                        │  »
#   q0_2: ───────┼─────────┼────┼─────────■────┼────┼───────────────────■────┼──»
#                │         │    │         │    │    │                   │    │  »
#   q0_3: ───────┼─────────┼────┼─────────┼────┼────┼─────────■─────────┼────┼──»
#                │         │    │         │    │    │         │         │    │  »
#   q1_0: ───────■─────────■────┼─────────■────┼────┼─────────■─────────┼────┼──»
# ...

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
c0 = QuantumRegister(5, 'c0')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, c0, t0)

# Function: main
initialize_register(qc, q0, 3, 4)
initialize_register(qc, q1, 2, 4)
qc.cx(q0[0], q3[0])
qc.cx(q1[0], q3[0])
qc.ccx(q0[0], q1[0], c0[1])
qc.cx(q0[1], q3[1])
qc.cx(q1[1], q3[1])
qc.ccx(q0[1], q1[1], c0[2])
qc.ccx(q3[1], c0[1], c0[2])
qc.cx(c0[1], q3[1])
qc.cx(q0[2], q3[2])
qc.cx(q1[2], q3[2])
qc.ccx(q0[2], q1[2], c0[3])
qc.ccx(q3[2], c0[2], c0[3])
qc.cx(c0[2], q3[2])
qc.cx(q0[3], q3[3])
qc.cx(q1[3], q3[3])
qc.ccx(q0[3], q1[3], c0[4])
qc.ccx(q3[3], c0[3], c0[4])
qc.cx(c0[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")

print(qc)
# Out:
# Measurement result: ClassicalRegister(4, 't0')
#
# Measurement results: {'0101': 1024}
# Circuit output: 5 (binary: 0101)
#       ┌───┐                                                                    »
# q0_0: ┤ X ├────────────■───────────────────────────────────────■───────────────»
#       ├───┤            │                                       │               »
# q0_1: ┤ X ├────────────┼────■──────────────────────────────────┼────■──────────»
#       └───┘            │    │                                  │    │          »
# q0_2: ───────■─────────┼────┼────────────────────────■─────────┼────┼──────────»
#              │         │    │                        │         │    │          »
# q0_3: ───────┼────■────┼────┼────────────────────────┼────■────┼────┼──────────»
#              │    │    │    │                        │    │    │    │          »
# q1_0: ───────┼────┼────┼────┼──────────────■─────────┼────┼────■────┼──────────»
# ...

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
inv0 = QuantumRegister(4, 'inv0')
one0 = QuantumRegister(4, 'one0')
b20 = QuantumRegister(4, 'b20')
c0 = QuantumRegister(5, 'c0')
c1 = QuantumRegister(5, 'c1')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, inv0, one0, b20, c0, c1, t0)

# Function: main
initialize_register(qc, q0, 3, 4)
initialize_register(qc, q1, 1, 4)
qc.cx(q1[0], inv0[0])
qc.x(inv0[0])
qc.cx(q1[1], inv0[1])
qc.x(inv0[1])
qc.cx(q1[2], inv0[2])
qc.x(inv0[2])
qc.cx(q1[3], inv0[3])
qc.x(inv0[3])
initialize_register(qc, one0, 1, 4)
qc.cx(inv0[0], b20[0])
qc.cx(one0[0], b20[0])
qc.ccx(inv0[0], one0[0], c0[1])
qc.cx(inv0[1], b20[1])
qc.cx(one0[1], b20[1])
qc.ccx(inv0[1], one0[1], c0[2])
qc.ccx(b20[1], c0[1], c0[2])
qc.cx(c0[1], b20[1])
qc.cx(inv0[2], b20[2])
qc.cx(one0[2], b20[2])
qc.ccx(inv0[2], one0[2], c0[3])
qc.ccx(b20[2], c0[2], c0[3])
qc.cx(c0[2], b20[2])
qc.cx(inv0[3], b20[3])
qc.cx(one0[3], b20[3])
qc.ccx(inv0[3], one0[3], c0[4])
qc.ccx(b20[3], c0[3], c0[4])
qc.cx(c0[3], b20[3])
qc.cx(q0[0], q3[0])
qc.cx(b20[0], q3[0])
qc.ccx(q0[0], b20[0], c1[1])
qc.cx(q0[1], q3[1])
qc.cx(b20[1], q3[1])
qc.ccx(q0[1], b20[1], c1[2])
qc.ccx(q3[1], c1[1], c1[2])
qc.cx(c1[1], q3[1])
qc.cx(q0[2], q3[2])
qc.cx(b20[2], q3[2])
qc.ccx(q0[2], b20[2], c1[3])
qc.ccx(q3[2], c1[2], c1[3])
qc.cx(c1[2], q3[2])
qc.cx(q0[3], q3[3])
qc.cx(b20[3], q3[3])
qc.ccx(q0[3], b20[3], c1[4])
qc.ccx(q3[3], c1[3], c1[4])
qc.cx(c1[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")

print(qc)
# Out:
# Measurement result: ClassicalRegister(4, 't0')
#
# Measurement results: {'0010': 1024}
# Circuit output: 2 (binary: 0010)
#         ┌───┐                                                                 »
#   q0_0: ┤ X ├───────────────────────────■─────────────────────────────────────»
#         ├───┤                           │                                     »
#   q0_1: ┤ X ├───────────────────────────┼────■────────────────────────────────»
#         └───┘                           │    │                                »
#   q0_2: ─────────────────■──────────────┼────┼────────────────────────────────»
#                          │              │    │                                »
#   q0_3: ─────────────────┼────■─────────┼────┼────────────────────────────────»
#         ┌───┐            │    │         │    │                                »
#   q1_0: ┤ X ├────────────┼────┼────■────┼────┼────────────────────────────────»
# ...

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
q4 = QuantumRegister(4, 'q4')
c0 = QuantumRegister(5, 'c0')
q5 = QuantumRegister(4, 'q5')
q6 = QuantumRegister(4, 'q6')
inv0 = QuantumRegister(4, 'inv0')
one0 = QuantumRegister(4, 'one0')
b20 = QuantumRegister(4, 'b20')
c1 = QuantumRegister(5, 'c1')
c2 = QuantumRegister(5, 'c2')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, q4, c0, q5, q6, inv0, one0, b20, c1, c2, t0)

# Function: main
initialize_register(qc, q0, 7, 4)
initialize_register(qc, q1, 2, 4)
initialize_register(qc, q2, 3, 4)
qc.cx(q0[0], q4[0])
qc.cx(q1[0], q4[0])
qc.ccx(q0[0], q1[0], c0[1])
qc.cx(q0[1], q4[1])
qc.cx(q1[1], q4[1])
qc.ccx(q0[1], q1[1], c0[2])
qc.ccx(q4[1], c0[1], c0[2])
qc.cx(c0[1], q4[1])
qc.cx(q0[2], q4[2])
qc.cx(q1[2], q4[2])
qc.ccx(q0[2], q1[2], c0[3])
qc.ccx(q4[2], c0[2], c0[3])
qc.cx(c0[2], q4[2])
qc.cx(q0[3], q4[3])
qc.cx(q1[3], q4[3])
qc.ccx(q0[3], q1[3], c0[4])
qc.ccx(q4[3], c0[3], c0[4])
qc.cx(c0[3], q4[3])
qc.cx(q2[0], inv0[0])
qc.x(inv0[0])
qc.cx(q2[1], inv0[1])
qc.x(inv0[1])
qc.cx(q2[2], inv0[2])
qc.x(inv0[2])
qc.cx(q2[3], inv0[3])
qc.x(inv0[3])
initialize_register(qc, one0, 1, 4)
qc.cx(inv0[0], b20[0])
qc.cx(one0[0], b20[0])
qc.ccx(inv0[0], one0[0], c1[1])
qc.cx(inv0[1], b20[1])
qc.cx(one0[1], b20[1])
qc.ccx(inv0[1], one0[1], c1[2])
qc.ccx(b20[1], c1[1], c1[2])
qc.cx(c1[1], b20[1])
qc.cx(inv0[2], b20[2])
qc.cx(one0[2], b20[2])
qc.ccx(inv0[2], one0[2], c1[3])
qc.ccx(b20[2], c1[2], c1[3])
qc.cx(c1[2], b20[2])
qc.cx(inv0[3], b20[3])
qc.cx(one0[3], b20[3])
qc.ccx(inv0[3], one0[3], c1[4])
qc.ccx(b20[3], c1[3], c1[4])
qc.cx(c1[3], b20[3])
qc.cx(q4[0], q6[0])
qc.cx(b20[0], q6[0])
qc.ccx(q4[0], b20[0], c2[1])
qc.cx(q4[1], q6[1])
qc.cx(b20[1], q6[1])
qc.ccx(q4[1], b20[1], c2[2])
qc.ccx(q6[1], c2[1], c2[2])
qc.cx(c2[1], q6[1])
qc.cx(q4[2], q6[2])
qc.cx(b20[2], q6[2])
qc.ccx(q4[2], b20[2], c2[3])
qc.ccx(q6[2], c2[2], c2[3])
qc.cx(c2[2], q6[2])
qc.cx(q4[3], q6[3])
qc.cx(b20[3], q6[3])
qc.ccx(q4[3], b20[3], c2[4])
qc.ccx(q6[3], c2[3], c2[4])
qc.cx(c2[3], q6[3])
qc.measure(q6, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")

print(qc)
# Out:
# Measurement result: ClassicalRegister(4, 't0')
#
# Measurement results: {'0110': 1024}
# Circuit output: 6 (binary: 0110)
#         ┌───┐                                                                 »
#   q0_0: ┤ X ├────────────■─────────────────────────────────────────────────■──»
#         ├───┤            │                                                 │  »
#   q0_1: ┤ X ├────────────┼────■────────────────────────────────────────────┼──»
#         ├───┤            │    │                                            │  »
#   q0_2: ┤ X ├────────────┼────┼────■───────────────────────────────────────┼──»
#         └───┘            │    │    │                                       │  »
#   q0_3: ───────■─────────┼────┼────┼──────────────────────────────────■────┼──»
#                │         │    │    │                                  │    │  »
#   q1_0: ───────┼─────────┼────┼────┼───────────────────■──────────────┼────■──»
# ...

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
dvd0 = QuantumRegister(4, 'dvd0')
dvs0 = QuantumRegister(4, 'dvs0')
q4 = QuantumRegister(4, 'q4')
r0 = QuantumRegister(8, 'r0')
shifted_r0 = QuantumRegister(8, 'shifted_r0')
upd_r0 = QuantumRegister(8, 'upd_r0')
upper_r0 = QuantumRegister(4, 'upper_r0')
cmp0 = QuantumRegister(1, 'cmp0')
b_inv0 = QuantumRegister(4, 'b_inv0')
one0 = QuantumRegister(4, 'one0')
b20 = QuantumRegister(4, 'b20')
c0 = QuantumRegister(5, 'c0')
diff0 = QuantumRegister(4, 'diff0')
c1 = QuantumRegister(5, 'c1')
neg_dvs0 = QuantumRegister(4, 'neg_dvs0')
one1 = QuantumRegister(4, 'one1')
twos0 = QuantumRegister(4, 'twos0')
c2 = QuantumRegister(5, 'c2')
sub_result0 = QuantumRegister(4, 'sub_result0')
c3 = QuantumRegister(5, 'c3')
new_r0 = QuantumRegister(8, 'new_r0')
ctrl0 = QuantumRegister(1, 'ctrl0')
xor0 = QuantumRegister(1, 'xor0')
final_ctrl0 = QuantumRegister(1, 'final_ctrl0')
ctrl1 = QuantumRegister(1, 'ctrl1')
xor1 = QuantumRegister(1, 'xor1')
final_ctrl1 = QuantumRegister(1, 'final_ctrl1')
ctrl2 = QuantumRegister(1, 'ctrl2')
xor2 = QuantumRegister(1, 'xor2')
final_ctrl2 = QuantumRegister(1, 'final_ctrl2')
ctrl3 = QuantumRegister(1, 'ctrl3')
xor3 = QuantumRegister(1, 'xor3')
final_ctrl3 = QuantumRegister(1, 'final_ctrl3')
shifted_r1 = QuantumRegister(8, 'shifted_r1')
upd_r1 = QuantumRegister(8, 'upd_r1')
upper_r1 = QuantumRegister(4, 'upper_r1')
cmp1 = QuantumRegister(1, 'cmp1')
b_inv1 = QuantumRegister(4, 'b_inv1')
one2 = QuantumRegister(4, 'one2')
b21 = QuantumRegister(4, 'b21')
c4 = QuantumRegister(5, 'c4')
diff1 = QuantumRegister(4, 'diff1')
c5 = QuantumRegister(5, 'c5')
neg_dvs1 = QuantumRegister(4, 'neg_dvs1')
one3 = QuantumRegister(4, 'one3')
twos1 = QuantumRegister(4, 'twos1')
c6 = QuantumRegister(5, 'c6')
sub_result1 = QuantumRegister(4, 'sub_result1')
c7 = QuantumRegister(5, 'c7')
new_r1 = QuantumRegister(8, 'new_r1')
ctrl4 = QuantumRegister(1, 'ctrl4')
xor4 = QuantumRegister(1, 'xor4')
final_ctrl4 = QuantumRegister(1, 'final_ctrl4')
ctrl5 = QuantumRegister(1, 'ctrl5')
xor5 = QuantumRegister(1, 'xor5')
final_ctrl5 = QuantumRegister(1, 'final_ctrl5')
ctrl6 = QuantumRegister(1, 'ctrl6')
xor6 = QuantumRegister(1, 'xor6')
final_ctrl6 = QuantumRegister(1, 'final_ctrl6')
ctrl7 = QuantumRegister(1, 'ctrl7')
xor7 = QuantumRegister(1, 'xor7')
final_ctrl7 = QuantumRegister(1, 'final_ctrl7')
shifted_r2 = QuantumRegister(8, 'shifted_r2')
upd_r2 = QuantumRegister(8, 'upd_r2')
upper_r2 = QuantumRegister(4, 'upper_r2')
cmp2 = QuantumRegister(1, 'cmp2')
b_inv2 = QuantumRegister(4, 'b_inv2')
one4 = QuantumRegister(4, 'one4')
b22 = QuantumRegister(4, 'b22')
c8 = QuantumRegister(5, 'c8')
diff2 = QuantumRegister(4, 'diff2')
c9 = QuantumRegister(5, 'c9')
neg_dvs2 = QuantumRegister(4, 'neg_dvs2')
one5 = QuantumRegister(4, 'one5')
twos2 = QuantumRegister(4, 'twos2')
c10 = QuantumRegister(5, 'c10')
sub_result2 = QuantumRegister(4, 'sub_result2')
c11 = QuantumRegister(5, 'c11')
new_r2 = QuantumRegister(8, 'new_r2')
ctrl8 = QuantumRegister(1, 'ctrl8')
xor8 = QuantumRegister(1, 'xor8')
final_ctrl8 = QuantumRegister(1, 'final_ctrl8')
ctrl9 = QuantumRegister(1, 'ctrl9')
xor9 = QuantumRegister(1, 'xor9')
final_ctrl9 = QuantumRegister(1, 'final_ctrl9')
ctrl10 = QuantumRegister(1, 'ctrl10')
xor10 = QuantumRegister(1, 'xor10')
final_ctrl10 = QuantumRegister(1, 'final_ctrl10')
ctrl11 = QuantumRegister(1, 'ctrl11')
xor11 = QuantumRegister(1, 'xor11')
final_ctrl11 = QuantumRegister(1, 'final_ctrl11')
shifted_r3 = QuantumRegister(8, 'shifted_r3')
upd_r3 = QuantumRegister(8, 'upd_r3')
upper_r3 = QuantumRegister(4, 'upper_r3')
cmp3 = QuantumRegister(1, 'cmp3')
b_inv3 = QuantumRegister(4, 'b_inv3')
one6 = QuantumRegister(4, 'one6')
b23 = QuantumRegister(4, 'b23')
c12 = QuantumRegister(5, 'c12')
diff3 = QuantumRegister(4, 'diff3')
c13 = QuantumRegister(5, 'c13')
neg_dvs3 = QuantumRegister(4, 'neg_dvs3')
one7 = QuantumRegister(4, 'one7')
twos3 = QuantumRegister(4, 'twos3')
c14 = QuantumRegister(5, 'c14')
sub_result3 = QuantumRegister(4, 'sub_result3')
c15 = QuantumRegister(5, 'c15')
new_r3 = QuantumRegister(8, 'new_r3')
ctrl12 = QuantumRegister(1, 'ctrl12')
xor12 = QuantumRegister(1, 'xor12')
final_ctrl12 = QuantumRegister(1, 'final_ctrl12')
ctrl13 = QuantumRegister(1, 'ctrl13')
xor13 = QuantumRegister(1, 'xor13')
final_ctrl13 = QuantumRegister(1, 'final_ctrl13')
ctrl14 = QuantumRegister(1, 'ctrl14')
xor14 = QuantumRegister(1, 'xor14')
final_ctrl14 = QuantumRegister(1, 'final_ctrl14')
ctrl15 = QuantumRegister(1, 'ctrl15')
xor15 = QuantumRegister(1, 'xor15')
final_ctrl15 = QuantumRegister(1, 'final_ctrl15')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, dvd0, dvs0, q4, r0, shifted_r0, upd_r0, upper_r0, cmp0, b_inv0, one0, b20, c0, diff0, c1, neg_dvs0, one1, twos0, c2, sub_result0, c3, new_r0, ctrl0, xor0, final_ctrl0, ctrl1, xor1, final_ctrl1, ctrl2, xor2, final_ctrl2, ctrl3, xor3, final_ctrl3, shifted_r1, upd_r1, upper_r1, cmp1, b_inv1, one2, b21, c4, diff1, c5, neg_dvs1, one3, twos1, c6, sub_result1, c7, new_r1, ctrl4, xor4, final_ctrl4, ctrl5, xor5, final_ctrl5, ctrl6, xor6, final_ctrl6, ctrl7, xor7, final_ctrl7, shifted_r2, upd_r2, upper_r2, cmp2, b_inv2, one4, b22, c8, diff2, c9, neg_dvs2, one5, twos2, c10, sub_result2, c11, new_r2, ctrl8, xor8, final_ctrl8, ctrl9, xor9, final_ctrl9, ctrl10, xor10, final_ctrl10, ctrl11, xor11, final_ctrl11, shifted_r3, upd_r3, upper_r3, cmp3, b_inv3, one6, b23, c12, diff3, c13, neg_dvs3, one7, twos3, c14, sub_result3, c15, new_r3, ctrl12, xor12, final_ctrl12, ctrl13, xor13, final_ctrl13, ctrl14, xor14, final_ctrl14, ctrl15, xor15, final_ctrl15, t0)

# Function: main
initialize_register(qc, q0, 6, 4)
initialize_register(qc, q1, 3, 4)
qc.cx(q0[0], dvd0[0])
qc.cx(q1[0], dvs0[0])
qc.cx(q0[1], dvd0[1])
qc.cx(q1[1], dvs0[1])
qc.cx(q0[2], dvd0[2])
qc.cx(q1[2], dvs0[2])
qc.cx(q0[3], dvd0[3])
qc.cx(q1[3], dvs0[3])
qc.cx(r0[0], shifted_r0[1])
qc.cx(r0[1], shifted_r0[2])
qc.cx(r0[2], shifted_r0[3])
qc.cx(r0[3], shifted_r0[4])
qc.cx(r0[4], shifted_r0[5])
qc.cx(r0[5], shifted_r0[6])
qc.cx(r0[6], shifted_r0[7])
qc.cx(dvd0[3], shifted_r0[0])
qc.cx(shifted_r0[0], upd_r0[0])
qc.cx(shifted_r0[1], upd_r0[1])
qc.cx(shifted_r0[2], upd_r0[2])
qc.cx(shifted_r0[3], upd_r0[3])
qc.cx(shifted_r0[4], upd_r0[4])
qc.cx(shifted_r0[5], upd_r0[5])
qc.cx(shifted_r0[6], upd_r0[6])
qc.cx(shifted_r0[7], upd_r0[7])
qc.cx(upd_r0[4], upper_r0[0])
qc.cx(upd_r0[5], upper_r0[1])
qc.cx(upd_r0[6], upper_r0[2])
qc.cx(upd_r0[7], upper_r0[3])
qc.cx(dvs0[0], b_inv0[0])
qc.x(b_inv0[0])
qc.cx(dvs0[1], b_inv0[1])
qc.x(b_inv0[1])
qc.cx(dvs0[2], b_inv0[2])
qc.x(b_inv0[2])
qc.cx(dvs0[3], b_inv0[3])
qc.x(b_inv0[3])
initialize_register(qc, one0, 1, 4)
qc.cx(b_inv0[0], b20[0])
qc.cx(one0[0], b20[0])
qc.ccx(b_inv0[0], one0[0], c0[1])
qc.cx(b_inv0[1], b20[1])
qc.cx(one0[1], b20[1])
qc.ccx(b_inv0[1], one0[1], c0[2])
qc.ccx(b20[1], c0[1], c0[2])
qc.cx(c0[1], b20[1])
qc.cx(b_inv0[2], b20[2])
qc.cx(one0[2], b20[2])
qc.ccx(b_inv0[2], one0[2], c0[3])
qc.ccx(b20[2], c0[2], c0[3])
qc.cx(c0[2], b20[2])
qc.cx(b_inv0[3], b20[3])
qc.cx(one0[3], b20[3])
qc.ccx(b_inv0[3], one0[3], c0[4])
qc.ccx(b20[3], c0[3], c0[4])
qc.cx(c0[3], b20[3])
qc.cx(upper_r0[0], diff0[0])
qc.cx(b20[0], diff0[0])
qc.ccx(upper_r0[0], b20[0], c1[1])
qc.cx(upper_r0[1], diff0[1])
qc.cx(b20[1], diff0[1])
qc.ccx(upper_r0[1], b20[1], c1[2])
qc.ccx(diff0[1], c1[1], c1[2])
qc.cx(c1[1], diff0[1])
qc.cx(upper_r0[2], diff0[2])
qc.cx(b20[2], diff0[2])
qc.ccx(upper_r0[2], b20[2], c1[3])
qc.ccx(diff0[2], c1[2], c1[3])
qc.cx(c1[2], diff0[2])
qc.cx(upper_r0[3], diff0[3])
qc.cx(b20[3], diff0[3])
qc.ccx(upper_r0[3], b20[3], c1[4])
qc.ccx(diff0[3], c1[3], c1[4])
qc.cx(c1[3], diff0[3])
qc.cx(diff0[3], cmp0[0])
qc.x(cmp0[0])
qc.cx(cmp0[0], q4[3])
initialize_register(qc, one1, 1, 4)
qc.cx(dvs0[0], neg_dvs0[0])
qc.x(neg_dvs0[0])
qc.cx(dvs0[1], neg_dvs0[1])
qc.x(neg_dvs0[1])
qc.cx(dvs0[2], neg_dvs0[2])
qc.x(neg_dvs0[2])
qc.cx(dvs0[3], neg_dvs0[3])
qc.x(neg_dvs0[3])
qc.cx(neg_dvs0[0], twos0[0])
qc.cx(one1[0], twos0[0])
qc.ccx(neg_dvs0[0], one1[0], c2[1])
qc.cx(neg_dvs0[1], twos0[1])
qc.cx(one1[1], twos0[1])
qc.ccx(neg_dvs0[1], one1[1], c2[2])
qc.ccx(twos0[1], c2[1], c2[2])
qc.cx(c2[1], twos0[1])
qc.cx(neg_dvs0[2], twos0[2])
qc.cx(one1[2], twos0[2])
qc.ccx(neg_dvs0[2], one1[2], c2[3])
qc.ccx(twos0[2], c2[2], c2[3])
qc.cx(c2[2], twos0[2])
qc.cx(neg_dvs0[3], twos0[3])
qc.cx(one1[3], twos0[3])
qc.ccx(neg_dvs0[3], one1[3], c2[4])
qc.ccx(twos0[3], c2[3], c2[4])
qc.cx(c2[3], twos0[3])
qc.cx(upper_r0[0], sub_result0[0])
qc.cx(twos0[0], sub_result0[0])
qc.ccx(upper_r0[0], twos0[0], c3[1])
qc.cx(upper_r0[1], sub_result0[1])
qc.cx(twos0[1], sub_result0[1])
qc.ccx(upper_r0[1], twos0[1], c3[2])
qc.ccx(sub_result0[1], c3[1], c3[2])
qc.cx(c3[1], sub_result0[1])
qc.cx(upper_r0[2], sub_result0[2])
qc.cx(twos0[2], sub_result0[2])
qc.ccx(upper_r0[2], twos0[2], c3[3])
qc.ccx(sub_result0[2], c3[2], c3[3])
qc.cx(c3[2], sub_result0[2])
qc.cx(upper_r0[3], sub_result0[3])
qc.cx(twos0[3], sub_result0[3])
qc.ccx(upper_r0[3], twos0[3], c3[4])
qc.ccx(sub_result0[3], c3[3], c3[4])
qc.cx(c3[3], sub_result0[3])
qc.cx(upd_r0[0], new_r0[0])
qc.cx(upper_r0[0], new_r0[4])
qc.cx(upd_r0[1], new_r0[1])
qc.cx(upper_r0[1], new_r0[5])
qc.cx(upd_r0[2], new_r0[2])
qc.cx(upper_r0[2], new_r0[6])
qc.cx(upd_r0[3], new_r0[3])
qc.cx(upper_r0[3], new_r0[7])
qc.cx(cmp0[0], ctrl0[0])
qc.x(ctrl0[0])
qc.cx(sub_result0[0], xor0[0])
qc.cx(upper_r0[0], xor0[0])
qc.ccx(ctrl0[0], xor0[0], final_ctrl0[0])
qc.cx(final_ctrl0[0], new_r0[4])
qc.cx(cmp0[0], ctrl1[0])
qc.x(ctrl1[0])
qc.cx(sub_result0[1], xor1[0])
qc.cx(upper_r0[1], xor1[0])
qc.ccx(ctrl1[0], xor1[0], final_ctrl1[0])
qc.cx(final_ctrl1[0], new_r0[5])
qc.cx(cmp0[0], ctrl2[0])
qc.x(ctrl2[0])
qc.cx(sub_result0[2], xor2[0])
qc.cx(upper_r0[2], xor2[0])
qc.ccx(ctrl2[0], xor2[0], final_ctrl2[0])
qc.cx(final_ctrl2[0], new_r0[6])
qc.cx(cmp0[0], ctrl3[0])
qc.x(ctrl3[0])
qc.cx(sub_result0[3], xor3[0])
qc.cx(upper_r0[3], xor3[0])
qc.ccx(ctrl3[0], xor3[0], final_ctrl3[0])
qc.cx(final_ctrl3[0], new_r0[7])
qc.cx(new_r0[0], shifted_r1[1])
qc.cx(new_r0[1], shifted_r1[2])
qc.cx(new_r0[2], shifted_r1[3])
qc.cx(new_r0[3], shifted_r1[4])
qc.cx(new_r0[4], shifted_r1[5])
qc.cx(new_r0[5], shifted_r1[6])
qc.cx(new_r0[6], shifted_r1[7])
qc.cx(dvd0[2], shifted_r1[0])
qc.cx(shifted_r1[0], upd_r1[0])
qc.cx(shifted_r1[1], upd_r1[1])
qc.cx(shifted_r1[2], upd_r1[2])
qc.cx(shifted_r1[3], upd_r1[3])
qc.cx(shifted_r1[4], upd_r1[4])
qc.cx(shifted_r1[5], upd_r1[5])
qc.cx(shifted_r1[6], upd_r1[6])
qc.cx(shifted_r1[7], upd_r1[7])
qc.cx(upd_r1[4], upper_r1[0])
qc.cx(upd_r1[5], upper_r1[1])
qc.cx(upd_r1[6], upper_r1[2])
qc.cx(upd_r1[7], upper_r1[3])
qc.cx(dvs0[0], b_inv1[0])
qc.x(b_inv1[0])
qc.cx(dvs0[1], b_inv1[1])
qc.x(b_inv1[1])
qc.cx(dvs0[2], b_inv1[2])
qc.x(b_inv1[2])
qc.cx(dvs0[3], b_inv1[3])
qc.x(b_inv1[3])
initialize_register(qc, one2, 1, 4)
qc.cx(b_inv1[0], b21[0])
qc.cx(one2[0], b21[0])
qc.ccx(b_inv1[0], one2[0], c4[1])
qc.cx(b_inv1[1], b21[1])
qc.cx(one2[1], b21[1])
qc.ccx(b_inv1[1], one2[1], c4[2])
qc.ccx(b21[1], c4[1], c4[2])
qc.cx(c4[1], b21[1])
qc.cx(b_inv1[2], b21[2])
qc.cx(one2[2], b21[2])
qc.ccx(b_inv1[2], one2[2], c4[3])
qc.ccx(b21[2], c4[2], c4[3])
qc.cx(c4[2], b21[2])
qc.cx(b_inv1[3], b21[3])
qc.cx(one2[3], b21[3])
qc.ccx(b_inv1[3], one2[3], c4[4])
qc.ccx(b21[3], c4[3], c4[4])
qc.cx(c4[3], b21[3])
qc.cx(upper_r1[0], diff1[0])
qc.cx(b21[0], diff1[0])
qc.ccx(upper_r1[0], b21[0], c5[1])
qc.cx(upper_r1[1], diff1[1])
qc.cx(b21[1], diff1[1])
qc.ccx(upper_r1[1], b21[1], c5[2])
qc.ccx(diff1[1], c5[1], c5[2])
qc.cx(c5[1], diff1[1])
qc.cx(upper_r1[2], diff1[2])
qc.cx(b21[2], diff1[2])
qc.ccx(upper_r1[2], b21[2], c5[3])
qc.ccx(diff1[2], c5[2], c5[3])
qc.cx(c5[2], diff1[2])
qc.cx(upper_r1[3], diff1[3])
qc.cx(b21[3], diff1[3])
qc.ccx(upper_r1[3], b21[3], c5[4])
qc.ccx(diff1[3], c5[3], c5[4])
qc.cx(c5[3], diff1[3])
qc.cx(diff1[3], cmp1[0])
qc.x(cmp1[0])
qc.cx(cmp1[0], q4[2])
initialize_register(qc, one3, 1, 4)
qc.cx(dvs0[0], neg_dvs1[0])
qc.x(neg_dvs1[0])
qc.cx(dvs0[1], neg_dvs1[1])
qc.x(neg_dvs1[1])
qc.cx(dvs0[2], neg_dvs1[2])
qc.x(neg_dvs1[2])
qc.cx(dvs0[3], neg_dvs1[3])
qc.x(neg_dvs1[3])
qc.cx(neg_dvs1[0], twos1[0])
qc.cx(one3[0], twos1[0])
qc.ccx(neg_dvs1[0], one3[0], c6[1])
qc.cx(neg_dvs1[1], twos1[1])
qc.cx(one3[1], twos1[1])
qc.ccx(neg_dvs1[1], one3[1], c6[2])
qc.ccx(twos1[1], c6[1], c6[2])
qc.cx(c6[1], twos1[1])
qc.cx(neg_dvs1[2], twos1[2])
qc.cx(one3[2], twos1[2])
qc.ccx(neg_dvs1[2], one3[2], c6[3])
qc.ccx(twos1[2], c6[2], c6[3])
qc.cx(c6[2], twos1[2])
qc.cx(neg_dvs1[3], twos1[3])
qc.cx(one3[3], twos1[3])
qc.ccx(neg_dvs1[3], one3[3], c6[4])
qc.ccx(twos1[3], c6[3], c6[4])
qc.cx(c6[3], twos1[3])
qc.cx(upper_r1[0], sub_result1[0])
qc.cx(twos1[0], sub_result1[0])
qc.ccx(upper_r1[0], twos1[0], c7[1])
qc.cx(upper_r1[1], sub_result1[1])
qc.cx(twos1[1], sub_result1[1])
qc.ccx(upper_r1[1], twos1[1], c7[2])
qc.ccx(sub_result1[1], c7[1], c7[2])
qc.cx(c7[1], sub_result1[1])
qc.cx(upper_r1[2], sub_result1[2])
qc.cx(twos1[2], sub_result1[2])
qc.ccx(upper_r1[2], twos1[2], c7[3])
qc.ccx(sub_result1[2], c7[2], c7[3])
qc.cx(c7[2], sub_result1[2])
qc.cx(upper_r1[3], sub_result1[3])
qc.cx(twos1[3], sub_result1[3])
qc.ccx(upper_r1[3], twos1[3], c7[4])
qc.ccx(sub_result1[3], c7[3], c7[4])
qc.cx(c7[3], sub_result1[3])
qc.cx(upd_r1[0], new_r1[0])
qc.cx(upper_r1[0], new_r1[4])
qc.cx(upd_r1[1], new_r1[1])
qc.cx(upper_r1[1], new_r1[5])
qc.cx(upd_r1[2], new_r1[2])
qc.cx(upper_r1[2], new_r1[6])
qc.cx(upd_r1[3], new_r1[3])
qc.cx(upper_r1[3], new_r1[7])
qc.cx(cmp1[0], ctrl4[0])
qc.x(ctrl4[0])
qc.cx(sub_result1[0], xor4[0])
qc.cx(upper_r1[0], xor4[0])
qc.ccx(ctrl4[0], xor4[0], final_ctrl4[0])
qc.cx(final_ctrl4[0], new_r1[4])
qc.cx(cmp1[0], ctrl5[0])
qc.x(ctrl5[0])
qc.cx(sub_result1[1], xor5[0])
qc.cx(upper_r1[1], xor5[0])
qc.ccx(ctrl5[0], xor5[0], final_ctrl5[0])
qc.cx(final_ctrl5[0], new_r1[5])
qc.cx(cmp1[0], ctrl6[0])
qc.x(ctrl6[0])
qc.cx(sub_result1[2], xor6[0])
qc.cx(upper_r1[2], xor6[0])
qc.ccx(ctrl6[0], xor6[0], final_ctrl6[0])
qc.cx(final_ctrl6[0], new_r1[6])
qc.cx(cmp1[0], ctrl7[0])
qc.x(ctrl7[0])
qc.cx(sub_result1[3], xor7[0])
qc.cx(upper_r1[3], xor7[0])
qc.ccx(ctrl7[0], xor7[0], final_ctrl7[0])
qc.cx(final_ctrl7[0], new_r1[7])
qc.cx(new_r1[0], shifted_r2[1])
qc.cx(new_r1[1], shifted_r2[2])
qc.cx(new_r1[2], shifted_r2[3])
qc.cx(new_r1[3], shifted_r2[4])
qc.cx(new_r1[4], shifted_r2[5])
qc.cx(new_r1[5], shifted_r2[6])
qc.cx(new_r1[6], shifted_r2[7])
qc.cx(dvd0[1], shifted_r2[0])
qc.cx(shifted_r2[0], upd_r2[0])
qc.cx(shifted_r2[1], upd_r2[1])
qc.cx(shifted_r2[2], upd_r2[2])
qc.cx(shifted_r2[3], upd_r2[3])
qc.cx(shifted_r2[4], upd_r2[4])
qc.cx(shifted_r2[5], upd_r2[5])
qc.cx(shifted_r2[6], upd_r2[6])
qc.cx(shifted_r2[7], upd_r2[7])
qc.cx(upd_r2[4], upper_r2[0])
qc.cx(upd_r2[5], upper_r2[1])
qc.cx(upd_r2[6], upper_r2[2])
qc.cx(upd_r2[7], upper_r2[3])
qc.cx(dvs0[0], b_inv2[0])
qc.x(b_inv2[0])
qc.cx(dvs0[1], b_inv2[1])
qc.x(b_inv2[1])
qc.cx(dvs0[2], b_inv2[2])
qc.x(b_inv2[2])
qc.cx(dvs0[3], b_inv2[3])
qc.x(b_inv2[3])
initialize_register(qc, one4, 1, 4)
qc.cx(b_inv2[0], b22[0])
qc.cx(one4[0], b22[0])
qc.ccx(b_inv2[0], one4[0], c8[1])
qc.cx(b_inv2[1], b22[1])
qc.cx(one4[1], b22[1])
qc.ccx(b_inv2[1], one4[1], c8[2])
qc.ccx(b22[1], c8[1], c8[2])
qc.cx(c8[1], b22[1])
qc.cx(b_inv2[2], b22[2])
qc.cx(one4[2], b22[2])
qc.ccx(b_inv2[2], one4[2], c8[3])
qc.ccx(b22[2], c8[2], c8[3])
qc.cx(c8[2], b22[2])
qc.cx(b_inv2[3], b22[3])
qc.cx(one4[3], b22[3])
qc.ccx(b_inv2[3], one4[3], c8[4])
qc.ccx(b22[3], c8[3], c8[4])
qc.cx(c8[3], b22[3])
qc.cx(upper_r2[0], diff2[0])
qc.cx(b22[0], diff2[0])
qc.ccx(upper_r2[0], b22[0], c9[1])
qc.cx(upper_r2[1], diff2[1])
qc.cx(b22[1], diff2[1])
qc.ccx(upper_r2[1], b22[1], c9[2])
qc.ccx(diff2[1], c9[1], c9[2])
qc.cx(c9[1], diff2[1])
qc.cx(upper_r2[2], diff2[2])
qc.cx(b22[2], diff2[2])
qc.ccx(upper_r2[2], b22[2], c9[3])
qc.ccx(diff2[2], c9[2], c9[3])
qc.cx(c9[2], diff2[2])
qc.cx(upper_r2[3], diff2[3])
qc.cx(b22[3], diff2[3])
qc.ccx(upper_r2[3], b22[3], c9[4])
qc.ccx(diff2[3], c9[3], c9[4])
qc.cx(c9[3], diff2[3])
qc.cx(diff2[3], cmp2[0])
qc.x(cmp2[0])
qc.cx(cmp2[0], q4[1])
initialize_register(qc, one5, 1, 4)
qc.cx(dvs0[0], neg_dvs2[0])
qc.x(neg_dvs2[0])
qc.cx(dvs0[1], neg_dvs2[1])
qc.x(neg_dvs2[1])
qc.cx(dvs0[2], neg_dvs2[2])
qc.x(neg_dvs2[2])
qc.cx(dvs0[3], neg_dvs2[3])
qc.x(neg_dvs2[3])
qc.cx(neg_dvs2[0], twos2[0])
qc.cx(one5[0], twos2[0])
qc.ccx(neg_dvs2[0], one5[0], c10[1])
qc.cx(neg_dvs2[1], twos2[1])
qc.cx(one5[1], twos2[1])
qc.ccx(neg_dvs2[1], one5[1], c10[2])
qc.ccx(twos2[1], c10[1], c10[2])
qc.cx(c10[1], twos2[1])
qc.cx(neg_dvs2[2], twos2[2])
qc.cx(one5[2], twos2[2])
qc.ccx(neg_dvs2[2], one5[2], c10[3])
qc.ccx(twos2[2], c10[2], c10[3])
qc.cx(c10[2], twos2[2])
qc.cx(neg_dvs2[3], twos2[3])
qc.cx(one5[3], twos2[3])
qc.ccx(neg_dvs2[3], one5[3], c10[4])
qc.ccx(twos2[3], c10[3], c10[4])
qc.cx(c10[3], twos2[3])
qc.cx(upper_r2[0], sub_result2[0])
qc.cx(twos2[0], sub_result2[0])
qc.ccx(upper_r2[0], twos2[0], c11[1])
qc.cx(upper_r2[1], sub_result2[1])
qc.cx(twos2[1], sub_result2[1])
qc.ccx(upper_r2[1], twos2[1], c11[2])
qc.ccx(sub_result2[1], c11[1], c11[2])
qc.cx(c11[1], sub_result2[1])
qc.cx(upper_r2[2], sub_result2[2])
qc.cx(twos2[2], sub_result2[2])
qc.ccx(upper_r2[2], twos2[2], c11[3])
qc.ccx(sub_result2[2], c11[2], c11[3])
qc.cx(c11[2], sub_result2[2])
qc.cx(upper_r2[3], sub_result2[3])
qc.cx(twos2[3], sub_result2[3])
qc.ccx(upper_r2[3], twos2[3], c11[4])
qc.ccx(sub_result2[3], c11[3], c11[4])
qc.cx(c11[3], sub_result2[3])
qc.cx(upd_r2[0], new_r2[0])
qc.cx(upper_r2[0], new_r2[4])
qc.cx(upd_r2[1], new_r2[1])
qc.cx(upper_r2[1], new_r2[5])
qc.cx(upd_r2[2], new_r2[2])
qc.cx(upper_r2[2], new_r2[6])
qc.cx(upd_r2[3], new_r2[3])
qc.cx(upper_r2[3], new_r2[7])
qc.cx(cmp2[0], ctrl8[0])
qc.x(ctrl8[0])
qc.cx(sub_result2[0], xor8[0])
qc.cx(upper_r2[0], xor8[0])
qc.ccx(ctrl8[0], xor8[0], final_ctrl8[0])
qc.cx(final_ctrl8[0], new_r2[4])
qc.cx(cmp2[0], ctrl9[0])
qc.x(ctrl9[0])
qc.cx(sub_result2[1], xor9[0])
qc.cx(upper_r2[1], xor9[0])
qc.ccx(ctrl9[0], xor9[0], final_ctrl9[0])
qc.cx(final_ctrl9[0], new_r2[5])
qc.cx(cmp2[0], ctrl10[0])
qc.x(ctrl10[0])
qc.cx(sub_result2[2], xor10[0])
qc.cx(upper_r2[2], xor10[0])
qc.ccx(ctrl10[0], xor10[0], final_ctrl10[0])
qc.cx(final_ctrl10[0], new_r2[6])
qc.cx(cmp2[0], ctrl11[0])
qc.x(ctrl11[0])
qc.cx(sub_result2[3], xor11[0])
qc.cx(upper_r2[3], xor11[0])
qc.ccx(ctrl11[0], xor11[0], final_ctrl11[0])
qc.cx(final_ctrl11[0], new_r2[7])
qc.cx(new_r2[0], shifted_r3[1])
qc.cx(new_r2[1], shifted_r3[2])
qc.cx(new_r2[2], shifted_r3[3])
qc.cx(new_r2[3], shifted_r3[4])
qc.cx(new_r2[4], shifted_r3[5])
qc.cx(new_r2[5], shifted_r3[6])
qc.cx(new_r2[6], shifted_r3[7])
qc.cx(dvd0[0], shifted_r3[0])
qc.cx(shifted_r3[0], upd_r3[0])
qc.cx(shifted_r3[1], upd_r3[1])
qc.cx(shifted_r3[2], upd_r3[2])
qc.cx(shifted_r3[3], upd_r3[3])
qc.cx(shifted_r3[4], upd_r3[4])
qc.cx(shifted_r3[5], upd_r3[5])
qc.cx(shifted_r3[6], upd_r3[6])
qc.cx(shifted_r3[7], upd_r3[7])
qc.cx(upd_r3[4], upper_r3[0])
qc.cx(upd_r3[5], upper_r3[1])
qc.cx(upd_r3[6], upper_r3[2])
qc.cx(upd_r3[7], upper_r3[3])
qc.cx(dvs0[0], b_inv3[0])
qc.x(b_inv3[0])
qc.cx(dvs0[1], b_inv3[1])
qc.x(b_inv3[1])
qc.cx(dvs0[2], b_inv3[2])
qc.x(b_inv3[2])
qc.cx(dvs0[3], b_inv3[3])
qc.x(b_inv3[3])
initialize_register(qc, one6, 1, 4)
qc.cx(b_inv3[0], b23[0])
qc.cx(one6[0], b23[0])
qc.ccx(b_inv3[0], one6[0], c12[1])
qc.cx(b_inv3[1], b23[1])
qc.cx(one6[1], b23[1])
qc.ccx(b_inv3[1], one6[1], c12[2])
qc.ccx(b23[1], c12[1], c12[2])
qc.cx(c12[1], b23[1])
qc.cx(b_inv3[2], b23[2])
qc.cx(one6[2], b23[2])
qc.ccx(b_inv3[2], one6[2], c12[3])
qc.ccx(b23[2], c12[2], c12[3])
qc.cx(c12[2], b23[2])
qc.cx(b_inv3[3], b23[3])
qc.cx(one6[3], b23[3])
qc.ccx(b_inv3[3], one6[3], c12[4])
qc.ccx(b23[3], c12[3], c12[4])
qc.cx(c12[3], b23[3])
qc.cx(upper_r3[0], diff3[0])
qc.cx(b23[0], diff3[0])
qc.ccx(upper_r3[0], b23[0], c13[1])
qc.cx(upper_r3[1], diff3[1])
qc.cx(b23[1], diff3[1])
qc.ccx(upper_r3[1], b23[1], c13[2])
qc.ccx(diff3[1], c13[1], c13[2])
qc.cx(c13[1], diff3[1])
qc.cx(upper_r3[2], diff3[2])
qc.cx(b23[2], diff3[2])
qc.ccx(upper_r3[2], b23[2], c13[3])
qc.ccx(diff3[2], c13[2], c13[3])
qc.cx(c13[2], diff3[2])
qc.cx(upper_r3[3], diff3[3])
qc.cx(b23[3], diff3[3])
qc.ccx(upper_r3[3], b23[3], c13[4])
qc.ccx(diff3[3], c13[3], c13[4])
qc.cx(c13[3], diff3[3])
qc.cx(diff3[3], cmp3[0])
qc.x(cmp3[0])
qc.cx(cmp3[0], q4[0])
initialize_register(qc, one7, 1, 4)
qc.cx(dvs0[0], neg_dvs3[0])
qc.x(neg_dvs3[0])
qc.cx(dvs0[1], neg_dvs3[1])
qc.x(neg_dvs3[1])
qc.cx(dvs0[2], neg_dvs3[2])
qc.x(neg_dvs3[2])
qc.cx(dvs0[3], neg_dvs3[3])
qc.x(neg_dvs3[3])
qc.cx(neg_dvs3[0], twos3[0])
qc.cx(one7[0], twos3[0])
qc.ccx(neg_dvs3[0], one7[0], c14[1])
qc.cx(neg_dvs3[1], twos3[1])
qc.cx(one7[1], twos3[1])
qc.ccx(neg_dvs3[1], one7[1], c14[2])
qc.ccx(twos3[1], c14[1], c14[2])
qc.cx(c14[1], twos3[1])
qc.cx(neg_dvs3[2], twos3[2])
qc.cx(one7[2], twos3[2])
qc.ccx(neg_dvs3[2], one7[2], c14[3])
qc.ccx(twos3[2], c14[2], c14[3])
qc.cx(c14[2], twos3[2])
qc.cx(neg_dvs3[3], twos3[3])
qc.cx(one7[3], twos3[3])
qc.ccx(neg_dvs3[3], one7[3], c14[4])
qc.ccx(twos3[3], c14[3], c14[4])
qc.cx(c14[3], twos3[3])
qc.cx(upper_r3[0], sub_result3[0])
qc.cx(twos3[0], sub_result3[0])
qc.ccx(upper_r3[0], twos3[0], c15[1])
qc.cx(upper_r3[1], sub_result3[1])
qc.cx(twos3[1], sub_result3[1])
qc.ccx(upper_r3[1], twos3[1], c15[2])
qc.ccx(sub_result3[1], c15[1], c15[2])
qc.cx(c15[1], sub_result3[1])
qc.cx(upper_r3[2], sub_result3[2])
qc.cx(twos3[2], sub_result3[2])
qc.ccx(upper_r3[2], twos3[2], c15[3])
qc.ccx(sub_result3[2], c15[2], c15[3])
qc.cx(c15[2], sub_result3[2])
qc.cx(upper_r3[3], sub_result3[3])
qc.cx(twos3[3], sub_result3[3])
qc.ccx(upper_r3[3], twos3[3], c15[4])
qc.ccx(sub_result3[3], c15[3], c15[4])
qc.cx(c15[3], sub_result3[3])
qc.cx(upd_r3[0], new_r3[0])
qc.cx(upper_r3[0], new_r3[4])
qc.cx(upd_r3[1], new_r3[1])
qc.cx(upper_r3[1], new_r3[5])
qc.cx(upd_r3[2], new_r3[2])
qc.cx(upper_r3[2], new_r3[6])
qc.cx(upd_r3[3], new_r3[3])
qc.cx(upper_r3[3], new_r3[7])
qc.cx(cmp3[0], ctrl12[0])
qc.x(ctrl12[0])
qc.cx(sub_result3[0], xor12[0])
qc.cx(upper_r3[0], xor12[0])
qc.ccx(ctrl12[0], xor12[0], final_ctrl12[0])
qc.cx(final_ctrl12[0], new_r3[4])
qc.cx(cmp3[0], ctrl13[0])
qc.x(ctrl13[0])
qc.cx(sub_result3[1], xor13[0])
qc.cx(upper_r3[1], xor13[0])
qc.ccx(ctrl13[0], xor13[0], final_ctrl13[0])
qc.cx(final_ctrl13[0], new_r3[5])
qc.cx(cmp3[0], ctrl14[0])
qc.x(ctrl14[0])
qc.cx(sub_result3[2], xor14[0])
qc.cx(upper_r3[2], xor14[0])
qc.ccx(ctrl14[0], xor14[0], final_ctrl14[0])
qc.cx(final_ctrl14[0], new_r3[6])
qc.cx(cmp3[0], ctrl15[0])
qc.x(ctrl15[0])
qc.cx(sub_result3[3], xor15[0])
qc.cx(upper_r3[3], xor15[0])
qc.ccx(ctrl15[0], xor15[0], final_ctrl15[0])
qc.cx(final_ctrl15[0], new_r3[7])
qc.cx(q4[0], q3[0])
qc.cx(q4[1], q3[1])
qc.cx(q4[2], q3[2])
qc.cx(q4[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")
# Out:
# Measurement result: ClassicalRegister(4, 't0')
#
# Measurement results: {'0011': 1024}
# Circuit output: 3 (binary: 0011)
