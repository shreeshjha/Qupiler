# %%
import qiskit

# %%
qiskit.__version__

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
inv0 = QuantumRegister(4, 'inv0')
c0 = QuantumRegister(5, 'c0')
t00 = QuantumRegister(1, 't00')
t10 = QuantumRegister(1, 't10')
t20 = QuantumRegister(1, 't20')
t30 = QuantumRegister(1, 't30')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, inv0, c0, t00, t10, t20, t30, t0)

# Function: main
initialize_register(qc, q0, 5, 4)
initialize_register(qc, q1, 1, 4)
qc.cx(q1[0], inv0[0])
qc.x(inv0[0])
qc.cx(q1[1], inv0[1])
qc.x(inv0[1])
qc.cx(q1[2], inv0[2])
qc.x(inv0[2])
qc.cx(q1[3], inv0[3])
qc.x(inv0[3])
qc.x(c0[0])
qc.cx(q0[0], q3[3])
qc.cx(inv0[0], q3[3])
qc.cx(c0[0], q3[3])
qc.ccx(q0[0], inv0[0], c0[1])
qc.ccx(q3[3], c0[0], t00[0])
qc.cx(t00[0], c0[1])
qc.cx(q0[1], q3[2])
qc.cx(inv0[1], q3[2])
qc.cx(c0[1], q3[2])
qc.ccx(q0[1], inv0[1], c0[2])
qc.ccx(q3[2], c0[1], t10[0])
qc.cx(t10[0], c0[2])
qc.cx(q0[2], q3[1])
qc.cx(inv0[2], q3[1])
qc.cx(c0[2], q3[1])
qc.ccx(q0[2], inv0[2], c0[3])
qc.ccx(q3[1], c0[2], t20[0])
qc.cx(t20[0], c0[3])
qc.cx(q0[3], q3[0])
qc.cx(inv0[3], q3[0])
qc.cx(c0[3], q3[0])
qc.ccx(q0[3], inv0[3], c0[4])
qc.ccx(q3[0], c0[3], t30[0])
qc.cx(t30[0], c0[4])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='automatic')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")

print("Circuit diagram:")
print(qc)

# You can uncomment the following line to show the circuit diagram graphically
# qc.draw(output='mpl').show()

# Run the circuit on the simulator
# simulator = AerSimulator()
# job = simulator.run(qc, shots=1024)
# result = job.result()
# counts = result.get_counts()
# print("\nMeasurement results:", counts)

# print('Measurement result:', t0)


# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization
# qc.decompose()
# print(qc)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
c0 = QuantumRegister(5, 'c0')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, c0, t0)

# Function: main
initialize_register(qc, q0, 7, 4)
initialize_register(qc, q1, 5, 4)
qc.cx(q0[0], q3[0])
qc.cx(q1[0], q3[0])
qc.ccx(q0[0], q1[0], c0[1])
qc.cx(q0[1], q3[1])
qc.cx(q1[1], q3[1])
qc.ccx(q0[1], q1[1], c0[2])
qc.ccx(q3[1], c0[1], c0[2])
qc.cx(c0[1], q3[1])
qc.cx(q0[2], q3[2])
qc.cx(q1[2], q3[2])
qc.ccx(q0[2], q1[2], c0[3])
qc.ccx(q3[2], c0[2], c0[3])
qc.cx(c0[2], q3[2])
qc.cx(q0[3], q3[3])
qc.cx(q1[3], q3[3])
qc.ccx(q0[3], q1[3], c0[4])
qc.ccx(q3[3], c0[3], c0[4])
qc.cx(c0[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='automatic')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")
    
print("Circuit diagram:")
print(qc)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
acc0 = QuantumRegister(8, 'acc0')
ctl0 = QuantumRegister(1, 'ctl0')
ctl1 = QuantumRegister(1, 'ctl1')
ctl2 = QuantumRegister(1, 'ctl2')
ctl3 = QuantumRegister(1, 'ctl3')
ctl4 = QuantumRegister(1, 'ctl4')
ctl5 = QuantumRegister(1, 'ctl5')
ctl6 = QuantumRegister(1, 'ctl6')
ctl7 = QuantumRegister(1, 'ctl7')
ctl8 = QuantumRegister(1, 'ctl8')
ctl9 = QuantumRegister(1, 'ctl9')
ctl10 = QuantumRegister(1, 'ctl10')
ctl11 = QuantumRegister(1, 'ctl11')
ctl12 = QuantumRegister(1, 'ctl12')
ctl13 = QuantumRegister(1, 'ctl13')
ctl14 = QuantumRegister(1, 'ctl14')
ctl15 = QuantumRegister(1, 'ctl15')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, acc0, ctl0, ctl1, ctl2, ctl3, ctl4, ctl5, ctl6, ctl7, ctl8, ctl9, ctl10, ctl11, ctl12, ctl13, ctl14, ctl15, t0)

# Function: main
initialize_register(qc, q0, 2, 4)
initialize_register(qc, q1, 4, 4)
qc.ccx(q1[0], q0[0], ctl0[0])
qc.cx(ctl0[0], acc0[0])
qc.ccx(q1[0], q0[1], ctl1[0])
qc.cx(ctl1[0], acc0[1])
qc.ccx(q1[0], q0[2], ctl2[0])
qc.cx(ctl2[0], acc0[2])
qc.ccx(q1[0], q0[3], ctl3[0])
qc.cx(ctl3[0], acc0[3])
qc.ccx(q1[1], q0[0], ctl4[0])
qc.cx(ctl4[0], acc0[1])
qc.ccx(q1[1], q0[1], ctl5[0])
qc.cx(ctl5[0], acc0[2])
qc.ccx(q1[1], q0[2], ctl6[0])
qc.cx(ctl6[0], acc0[3])
qc.ccx(q1[1], q0[3], ctl7[0])
qc.cx(ctl7[0], acc0[4])
qc.ccx(q1[2], q0[0], ctl8[0])
qc.cx(ctl8[0], acc0[2])
qc.ccx(q1[2], q0[1], ctl9[0])
qc.cx(ctl9[0], acc0[3])
qc.ccx(q1[2], q0[2], ctl10[0])
qc.cx(ctl10[0], acc0[4])
qc.ccx(q1[2], q0[3], ctl11[0])
qc.cx(ctl11[0], acc0[5])
qc.ccx(q1[3], q0[0], ctl12[0])
qc.cx(ctl12[0], acc0[3])
qc.ccx(q1[3], q0[1], ctl13[0])
qc.cx(ctl13[0], acc0[4])
qc.ccx(q1[3], q0[2], ctl14[0])
qc.cx(ctl14[0], acc0[5])
qc.ccx(q1[3], q0[3], ctl15[0])
qc.cx(ctl15[0], acc0[6])
qc.cx(acc0[0], q3[0])
qc.cx(acc0[1], q3[1])
qc.cx(acc0[2], q3[2])
qc.cx(acc0[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")

print(qc)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
c0 = QuantumRegister(5, 'c0')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, c0, t0)

# Function: main
initialize_register(qc, q0, 3, 4)
initialize_register(qc, q1, 2, 4)
qc.cx(q0[0], q3[0])
qc.cx(q1[0], q3[0])
qc.ccx(q0[0], q1[0], c0[1])
qc.cx(q0[1], q3[1])
qc.cx(q1[1], q3[1])
qc.ccx(q0[1], q1[1], c0[2])
qc.ccx(q3[1], c0[1], c0[2])
qc.cx(c0[1], q3[1])
qc.cx(q0[2], q3[2])
qc.cx(q1[2], q3[2])
qc.ccx(q0[2], q1[2], c0[3])
qc.ccx(q3[2], c0[2], c0[3])
qc.cx(c0[2], q3[2])
qc.cx(q0[3], q3[3])
qc.cx(q1[3], q3[3])
qc.ccx(q0[3], q1[3], c0[4])
qc.ccx(q3[3], c0[3], c0[4])
qc.cx(c0[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")

print(qc)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
inv0 = QuantumRegister(4, 'inv0')
one0 = QuantumRegister(4, 'one0')
b20 = QuantumRegister(4, 'b20')
c0 = QuantumRegister(5, 'c0')
c1 = QuantumRegister(5, 'c1')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, inv0, one0, b20, c0, c1, t0)

# Function: main
initialize_register(qc, q0, 3, 4)
initialize_register(qc, q1, 1, 4)
qc.cx(q1[0], inv0[0])
qc.x(inv0[0])
qc.cx(q1[1], inv0[1])
qc.x(inv0[1])
qc.cx(q1[2], inv0[2])
qc.x(inv0[2])
qc.cx(q1[3], inv0[3])
qc.x(inv0[3])
initialize_register(qc, one0, 1, 4)
qc.cx(inv0[0], b20[0])
qc.cx(one0[0], b20[0])
qc.ccx(inv0[0], one0[0], c0[1])
qc.cx(inv0[1], b20[1])
qc.cx(one0[1], b20[1])
qc.ccx(inv0[1], one0[1], c0[2])
qc.ccx(b20[1], c0[1], c0[2])
qc.cx(c0[1], b20[1])
qc.cx(inv0[2], b20[2])
qc.cx(one0[2], b20[2])
qc.ccx(inv0[2], one0[2], c0[3])
qc.ccx(b20[2], c0[2], c0[3])
qc.cx(c0[2], b20[2])
qc.cx(inv0[3], b20[3])
qc.cx(one0[3], b20[3])
qc.ccx(inv0[3], one0[3], c0[4])
qc.ccx(b20[3], c0[3], c0[4])
qc.cx(c0[3], b20[3])
qc.cx(q0[0], q3[0])
qc.cx(b20[0], q3[0])
qc.ccx(q0[0], b20[0], c1[1])
qc.cx(q0[1], q3[1])
qc.cx(b20[1], q3[1])
qc.ccx(q0[1], b20[1], c1[2])
qc.ccx(q3[1], c1[1], c1[2])
qc.cx(c1[1], q3[1])
qc.cx(q0[2], q3[2])
qc.cx(b20[2], q3[2])
qc.ccx(q0[2], b20[2], c1[3])
qc.ccx(q3[2], c1[2], c1[3])
qc.cx(c1[2], q3[2])
qc.cx(q0[3], q3[3])
qc.cx(b20[3], q3[3])
qc.ccx(q0[3], b20[3], c1[4])
qc.ccx(q3[3], c1[3], c1[4])
qc.cx(c1[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")

print(qc)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
q4 = QuantumRegister(4, 'q4')
c0 = QuantumRegister(5, 'c0')
q5 = QuantumRegister(4, 'q5')
q6 = QuantumRegister(4, 'q6')
inv0 = QuantumRegister(4, 'inv0')
one0 = QuantumRegister(4, 'one0')
b20 = QuantumRegister(4, 'b20')
c1 = QuantumRegister(5, 'c1')
c2 = QuantumRegister(5, 'c2')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, q4, c0, q5, q6, inv0, one0, b20, c1, c2, t0)

# Function: main
initialize_register(qc, q0, 7, 4)
initialize_register(qc, q1, 2, 4)
initialize_register(qc, q2, 3, 4)
qc.cx(q0[0], q4[0])
qc.cx(q1[0], q4[0])
qc.ccx(q0[0], q1[0], c0[1])
qc.cx(q0[1], q4[1])
qc.cx(q1[1], q4[1])
qc.ccx(q0[1], q1[1], c0[2])
qc.ccx(q4[1], c0[1], c0[2])
qc.cx(c0[1], q4[1])
qc.cx(q0[2], q4[2])
qc.cx(q1[2], q4[2])
qc.ccx(q0[2], q1[2], c0[3])
qc.ccx(q4[2], c0[2], c0[3])
qc.cx(c0[2], q4[2])
qc.cx(q0[3], q4[3])
qc.cx(q1[3], q4[3])
qc.ccx(q0[3], q1[3], c0[4])
qc.ccx(q4[3], c0[3], c0[4])
qc.cx(c0[3], q4[3])
qc.cx(q2[0], inv0[0])
qc.x(inv0[0])
qc.cx(q2[1], inv0[1])
qc.x(inv0[1])
qc.cx(q2[2], inv0[2])
qc.x(inv0[2])
qc.cx(q2[3], inv0[3])
qc.x(inv0[3])
initialize_register(qc, one0, 1, 4)
qc.cx(inv0[0], b20[0])
qc.cx(one0[0], b20[0])
qc.ccx(inv0[0], one0[0], c1[1])
qc.cx(inv0[1], b20[1])
qc.cx(one0[1], b20[1])
qc.ccx(inv0[1], one0[1], c1[2])
qc.ccx(b20[1], c1[1], c1[2])
qc.cx(c1[1], b20[1])
qc.cx(inv0[2], b20[2])
qc.cx(one0[2], b20[2])
qc.ccx(inv0[2], one0[2], c1[3])
qc.ccx(b20[2], c1[2], c1[3])
qc.cx(c1[2], b20[2])
qc.cx(inv0[3], b20[3])
qc.cx(one0[3], b20[3])
qc.ccx(inv0[3], one0[3], c1[4])
qc.ccx(b20[3], c1[3], c1[4])
qc.cx(c1[3], b20[3])
qc.cx(q4[0], q6[0])
qc.cx(b20[0], q6[0])
qc.ccx(q4[0], b20[0], c2[1])
qc.cx(q4[1], q6[1])
qc.cx(b20[1], q6[1])
qc.ccx(q4[1], b20[1], c2[2])
qc.ccx(q6[1], c2[1], c2[2])
qc.cx(c2[1], q6[1])
qc.cx(q4[2], q6[2])
qc.cx(b20[2], q6[2])
qc.ccx(q4[2], b20[2], c2[3])
qc.ccx(q6[2], c2[2], c2[3])
qc.cx(c2[2], q6[2])
qc.cx(q4[3], q6[3])
qc.cx(b20[3], q6[3])
qc.ccx(q4[3], b20[3], c2[4])
qc.ccx(q6[3], c2[3], c2[4])
qc.cx(c2[3], q6[3])
qc.measure(q6, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")

print(qc)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
rem0 = QuantumRegister(5, 'rem0')
quot0 = QuantumRegister(4, 'quot0')
upper_rem0 = QuantumRegister(4, 'upper_rem0')
diff0 = QuantumRegister(4, 'diff0')
inv0 = QuantumRegister(4, 'inv0')
one0 = QuantumRegister(4, 'one0')
b20 = QuantumRegister(4, 'b20')
c0 = QuantumRegister(5, 'c0')
c1 = QuantumRegister(5, 'c1')
sign0 = QuantumRegister(1, 'sign0')
tmp0 = QuantumRegister(1, 'tmp0')
tmp1 = QuantumRegister(1, 'tmp1')
tmp2 = QuantumRegister(1, 'tmp2')
tmp3 = QuantumRegister(1, 'tmp3')
upper_rem1 = QuantumRegister(4, 'upper_rem1')
diff1 = QuantumRegister(4, 'diff1')
inv1 = QuantumRegister(4, 'inv1')
one1 = QuantumRegister(4, 'one1')
b21 = QuantumRegister(4, 'b21')
c2 = QuantumRegister(5, 'c2')
c3 = QuantumRegister(5, 'c3')
sign1 = QuantumRegister(1, 'sign1')
tmp4 = QuantumRegister(1, 'tmp4')
tmp5 = QuantumRegister(1, 'tmp5')
tmp6 = QuantumRegister(1, 'tmp6')
tmp7 = QuantumRegister(1, 'tmp7')
upper_rem2 = QuantumRegister(4, 'upper_rem2')
diff2 = QuantumRegister(4, 'diff2')
inv2 = QuantumRegister(4, 'inv2')
one2 = QuantumRegister(4, 'one2')
b22 = QuantumRegister(4, 'b22')
c4 = QuantumRegister(5, 'c4')
c5 = QuantumRegister(5, 'c5')
sign2 = QuantumRegister(1, 'sign2')
tmp8 = QuantumRegister(1, 'tmp8')
tmp9 = QuantumRegister(1, 'tmp9')
tmp10 = QuantumRegister(1, 'tmp10')
tmp11 = QuantumRegister(1, 'tmp11')
upper_rem3 = QuantumRegister(4, 'upper_rem3')
diff3 = QuantumRegister(4, 'diff3')
inv3 = QuantumRegister(4, 'inv3')
one3 = QuantumRegister(4, 'one3')
b23 = QuantumRegister(4, 'b23')
c6 = QuantumRegister(5, 'c6')
c7 = QuantumRegister(5, 'c7')
sign3 = QuantumRegister(1, 'sign3')
tmp12 = QuantumRegister(1, 'tmp12')
tmp13 = QuantumRegister(1, 'tmp13')
tmp14 = QuantumRegister(1, 'tmp14')
tmp15 = QuantumRegister(1, 'tmp15')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, rem0, quot0, upper_rem0, diff0, inv0, one0, b20, c0, c1, sign0, tmp0, tmp1, tmp2, tmp3, upper_rem1, diff1, inv1, one1, b21, c2, c3, sign1, tmp4, tmp5, tmp6, tmp7, upper_rem2, diff2, inv2, one2, b22, c4, c5, sign2, tmp8, tmp9, tmp10, tmp11, upper_rem3, diff3, inv3, one3, b23, c6, c7, sign3, tmp12, tmp13, tmp14, tmp15, t0)

# Function: main
initialize_register(qc, q0, 6, 4)
initialize_register(qc, q1, 2, 4)
initialize_register(qc, rem0, 0, 5)
initialize_register(qc, quot0, 0, 4)
qc.cx(rem0[3], rem0[4])
qc.cx(rem0[2], rem0[3])
qc.cx(rem0[1], rem0[2])
qc.cx(rem0[0], rem0[1])
qc.cx(q0[3], rem0[0])
qc.cx(rem0[1], upper_rem0[0])
qc.cx(rem0[2], upper_rem0[1])
qc.cx(rem0[3], upper_rem0[2])
qc.cx(rem0[4], upper_rem0[3])
qc.cx(q1[0], inv0[0])
qc.x(inv0[0])
qc.cx(q1[1], inv0[1])
qc.x(inv0[1])
qc.cx(q1[2], inv0[2])
qc.x(inv0[2])
qc.cx(q1[3], inv0[3])
qc.x(inv0[3])
initialize_register(qc, one0, 1, 4)
qc.cx(inv0[0], b20[0])
qc.cx(one0[0], b20[0])
qc.ccx(inv0[0], one0[0], c0[1])
qc.cx(inv0[1], b20[1])
qc.cx(one0[1], b20[1])
qc.ccx(inv0[1], one0[1], c0[2])
qc.ccx(b20[1], c0[1], c0[2])
qc.cx(c0[1], b20[1])
qc.cx(inv0[2], b20[2])
qc.cx(one0[2], b20[2])
qc.ccx(inv0[2], one0[2], c0[3])
qc.ccx(b20[2], c0[2], c0[3])
qc.cx(c0[2], b20[2])
qc.cx(inv0[3], b20[3])
qc.cx(one0[3], b20[3])
qc.ccx(inv0[3], one0[3], c0[4])
qc.ccx(b20[3], c0[3], c0[4])
qc.cx(c0[3], b20[3])
qc.cx(upper_rem0[0], diff0[0])
qc.cx(b20[0], diff0[0])
qc.ccx(upper_rem0[0], b20[0], c1[1])
qc.cx(upper_rem0[1], diff0[1])
qc.cx(b20[1], diff0[1])
qc.ccx(upper_rem0[1], b20[1], c1[2])
qc.ccx(diff0[1], c1[1], c1[2])
qc.cx(c1[1], diff0[1])
qc.cx(upper_rem0[2], diff0[2])
qc.cx(b20[2], diff0[2])
qc.ccx(upper_rem0[2], b20[2], c1[3])
qc.ccx(diff0[2], c1[2], c1[3])
qc.cx(c1[2], diff0[2])
qc.cx(upper_rem0[3], diff0[3])
qc.cx(b20[3], diff0[3])
qc.ccx(upper_rem0[3], b20[3], c1[4])
qc.ccx(diff0[3], c1[3], c1[4])
qc.cx(c1[3], diff0[3])
qc.cx(diff0[3], sign0[0])
qc.x(sign0[0])
qc.cx(sign0[0], quot0[3])
qc.cx(diff0[0], tmp0[0])
qc.cx(rem0[1], tmp0[0])
qc.ccx(sign0[0], tmp0[0], rem0[1])
qc.cx(diff0[1], tmp1[0])
qc.cx(rem0[2], tmp1[0])
qc.ccx(sign0[0], tmp1[0], rem0[2])
qc.cx(diff0[2], tmp2[0])
qc.cx(rem0[3], tmp2[0])
qc.ccx(sign0[0], tmp2[0], rem0[3])
qc.cx(diff0[3], tmp3[0])
qc.cx(rem0[4], tmp3[0])
qc.ccx(sign0[0], tmp3[0], rem0[4])
qc.cx(rem0[3], rem0[4])
qc.cx(rem0[2], rem0[3])
qc.cx(rem0[1], rem0[2])
qc.cx(rem0[0], rem0[1])
qc.cx(q0[2], rem0[0])
qc.cx(rem0[1], upper_rem1[0])
qc.cx(rem0[2], upper_rem1[1])
qc.cx(rem0[3], upper_rem1[2])
qc.cx(rem0[4], upper_rem1[3])
qc.cx(q1[0], inv1[0])
qc.x(inv1[0])
qc.cx(q1[1], inv1[1])
qc.x(inv1[1])
qc.cx(q1[2], inv1[2])
qc.x(inv1[2])
qc.cx(q1[3], inv1[3])
qc.x(inv1[3])
initialize_register(qc, one1, 1, 4)
qc.cx(inv1[0], b21[0])
qc.cx(one1[0], b21[0])
qc.ccx(inv1[0], one1[0], c2[1])
qc.cx(inv1[1], b21[1])
qc.cx(one1[1], b21[1])
qc.ccx(inv1[1], one1[1], c2[2])
qc.ccx(b21[1], c2[1], c2[2])
qc.cx(c2[1], b21[1])
qc.cx(inv1[2], b21[2])
qc.cx(one1[2], b21[2])
qc.ccx(inv1[2], one1[2], c2[3])
qc.ccx(b21[2], c2[2], c2[3])
qc.cx(c2[2], b21[2])
qc.cx(inv1[3], b21[3])
qc.cx(one1[3], b21[3])
qc.ccx(inv1[3], one1[3], c2[4])
qc.ccx(b21[3], c2[3], c2[4])
qc.cx(c2[3], b21[3])
qc.cx(upper_rem1[0], diff1[0])
qc.cx(b21[0], diff1[0])
qc.ccx(upper_rem1[0], b21[0], c3[1])
qc.cx(upper_rem1[1], diff1[1])
qc.cx(b21[1], diff1[1])
qc.ccx(upper_rem1[1], b21[1], c3[2])
qc.ccx(diff1[1], c3[1], c3[2])
qc.cx(c3[1], diff1[1])
qc.cx(upper_rem1[2], diff1[2])
qc.cx(b21[2], diff1[2])
qc.ccx(upper_rem1[2], b21[2], c3[3])
qc.ccx(diff1[2], c3[2], c3[3])
qc.cx(c3[2], diff1[2])
qc.cx(upper_rem1[3], diff1[3])
qc.cx(b21[3], diff1[3])
qc.ccx(upper_rem1[3], b21[3], c3[4])
qc.ccx(diff1[3], c3[3], c3[4])
qc.cx(c3[3], diff1[3])
qc.cx(diff1[3], sign1[0])
qc.x(sign1[0])
qc.cx(sign1[0], quot0[2])
qc.cx(diff1[0], tmp4[0])
qc.cx(rem0[1], tmp4[0])
qc.ccx(sign1[0], tmp4[0], rem0[1])
qc.cx(diff1[1], tmp5[0])
qc.cx(rem0[2], tmp5[0])
qc.ccx(sign1[0], tmp5[0], rem0[2])
qc.cx(diff1[2], tmp6[0])
qc.cx(rem0[3], tmp6[0])
qc.ccx(sign1[0], tmp6[0], rem0[3])
qc.cx(diff1[3], tmp7[0])
qc.cx(rem0[4], tmp7[0])
qc.ccx(sign1[0], tmp7[0], rem0[4])
qc.cx(rem0[3], rem0[4])
qc.cx(rem0[2], rem0[3])
qc.cx(rem0[1], rem0[2])
qc.cx(rem0[0], rem0[1])
qc.cx(q0[1], rem0[0])
qc.cx(rem0[1], upper_rem2[0])
qc.cx(rem0[2], upper_rem2[1])
qc.cx(rem0[3], upper_rem2[2])
qc.cx(rem0[4], upper_rem2[3])
qc.cx(q1[0], inv2[0])
qc.x(inv2[0])
qc.cx(q1[1], inv2[1])
qc.x(inv2[1])
qc.cx(q1[2], inv2[2])
qc.x(inv2[2])
qc.cx(q1[3], inv2[3])
qc.x(inv2[3])
initialize_register(qc, one2, 1, 4)
qc.cx(inv2[0], b22[0])
qc.cx(one2[0], b22[0])
qc.ccx(inv2[0], one2[0], c4[1])
qc.cx(inv2[1], b22[1])
qc.cx(one2[1], b22[1])
qc.ccx(inv2[1], one2[1], c4[2])
qc.ccx(b22[1], c4[1], c4[2])
qc.cx(c4[1], b22[1])
qc.cx(inv2[2], b22[2])
qc.cx(one2[2], b22[2])
qc.ccx(inv2[2], one2[2], c4[3])
qc.ccx(b22[2], c4[2], c4[3])
qc.cx(c4[2], b22[2])
qc.cx(inv2[3], b22[3])
qc.cx(one2[3], b22[3])
qc.ccx(inv2[3], one2[3], c4[4])
qc.ccx(b22[3], c4[3], c4[4])
qc.cx(c4[3], b22[3])
qc.cx(upper_rem2[0], diff2[0])
qc.cx(b22[0], diff2[0])
qc.ccx(upper_rem2[0], b22[0], c5[1])
qc.cx(upper_rem2[1], diff2[1])
qc.cx(b22[1], diff2[1])
qc.ccx(upper_rem2[1], b22[1], c5[2])
qc.ccx(diff2[1], c5[1], c5[2])
qc.cx(c5[1], diff2[1])
qc.cx(upper_rem2[2], diff2[2])
qc.cx(b22[2], diff2[2])
qc.ccx(upper_rem2[2], b22[2], c5[3])
qc.ccx(diff2[2], c5[2], c5[3])
qc.cx(c5[2], diff2[2])
qc.cx(upper_rem2[3], diff2[3])
qc.cx(b22[3], diff2[3])
qc.ccx(upper_rem2[3], b22[3], c5[4])
qc.ccx(diff2[3], c5[3], c5[4])
qc.cx(c5[3], diff2[3])
qc.cx(diff2[3], sign2[0])
qc.x(sign2[0])
qc.cx(sign2[0], quot0[1])
qc.cx(diff2[0], tmp8[0])
qc.cx(rem0[1], tmp8[0])
qc.ccx(sign2[0], tmp8[0], rem0[1])
qc.cx(diff2[1], tmp9[0])
qc.cx(rem0[2], tmp9[0])
qc.ccx(sign2[0], tmp9[0], rem0[2])
qc.cx(diff2[2], tmp10[0])
qc.cx(rem0[3], tmp10[0])
qc.ccx(sign2[0], tmp10[0], rem0[3])
qc.cx(diff2[3], tmp11[0])
qc.cx(rem0[4], tmp11[0])
qc.ccx(sign2[0], tmp11[0], rem0[4])
qc.cx(rem0[3], rem0[4])
qc.cx(rem0[2], rem0[3])
qc.cx(rem0[1], rem0[2])
qc.cx(rem0[0], rem0[1])
qc.cx(q0[0], rem0[0])
qc.cx(rem0[1], upper_rem3[0])
qc.cx(rem0[2], upper_rem3[1])
qc.cx(rem0[3], upper_rem3[2])
qc.cx(rem0[4], upper_rem3[3])
qc.cx(q1[0], inv3[0])
qc.x(inv3[0])
qc.cx(q1[1], inv3[1])
qc.x(inv3[1])
qc.cx(q1[2], inv3[2])
qc.x(inv3[2])
qc.cx(q1[3], inv3[3])
qc.x(inv3[3])
initialize_register(qc, one3, 1, 4)
qc.cx(inv3[0], b23[0])
qc.cx(one3[0], b23[0])
qc.ccx(inv3[0], one3[0], c6[1])
qc.cx(inv3[1], b23[1])
qc.cx(one3[1], b23[1])
qc.ccx(inv3[1], one3[1], c6[2])
qc.ccx(b23[1], c6[1], c6[2])
qc.cx(c6[1], b23[1])
qc.cx(inv3[2], b23[2])
qc.cx(one3[2], b23[2])
qc.ccx(inv3[2], one3[2], c6[3])
qc.ccx(b23[2], c6[2], c6[3])
qc.cx(c6[2], b23[2])
qc.cx(inv3[3], b23[3])
qc.cx(one3[3], b23[3])
qc.ccx(inv3[3], one3[3], c6[4])
qc.ccx(b23[3], c6[3], c6[4])
qc.cx(c6[3], b23[3])
qc.cx(upper_rem3[0], diff3[0])
qc.cx(b23[0], diff3[0])
qc.ccx(upper_rem3[0], b23[0], c7[1])
qc.cx(upper_rem3[1], diff3[1])
qc.cx(b23[1], diff3[1])
qc.ccx(upper_rem3[1], b23[1], c7[2])
qc.ccx(diff3[1], c7[1], c7[2])
qc.cx(c7[1], diff3[1])
qc.cx(upper_rem3[2], diff3[2])
qc.cx(b23[2], diff3[2])
qc.ccx(upper_rem3[2], b23[2], c7[3])
qc.ccx(diff3[2], c7[2], c7[3])
qc.cx(c7[2], diff3[2])
qc.cx(upper_rem3[3], diff3[3])
qc.cx(b23[3], diff3[3])
qc.ccx(upper_rem3[3], b23[3], c7[4])
qc.ccx(diff3[3], c7[3], c7[4])
qc.cx(c7[3], diff3[3])
qc.cx(diff3[3], sign3[0])
qc.x(sign3[0])
qc.cx(sign3[0], quot0[0])
qc.cx(diff3[0], tmp12[0])
qc.cx(rem0[1], tmp12[0])
qc.ccx(sign3[0], tmp12[0], rem0[1])
qc.cx(diff3[1], tmp13[0])
qc.cx(rem0[2], tmp13[0])
qc.ccx(sign3[0], tmp13[0], rem0[2])
qc.cx(diff3[2], tmp14[0])
qc.cx(rem0[3], tmp14[0])
qc.ccx(sign3[0], tmp14[0], rem0[3])
qc.cx(diff3[3], tmp15[0])
qc.cx(rem0[4], tmp15[0])
qc.ccx(sign3[0], tmp15[0], rem0[4])
qc.cx(quot0[0], q3[0])
qc.cx(quot0[1], q3[1])
qc.cx(quot0[2], q3[2])
qc.cx(quot0[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")
# Out:
# Measurement result: ClassicalRegister(4, 't0')
#
# Measurement results: {'0001': 1024}
# Circuit output: 1 (binary: 0001)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
quot0 = QuantumRegister(4, 'quot0')
rem0 = QuantumRegister(4, 'rem0')
shifted_rem0 = QuantumRegister(4, 'shifted_rem0')
diff0 = QuantumRegister(4, 'diff0')
inv0 = QuantumRegister(4, 'inv0')
one0 = QuantumRegister(4, 'one0')
b20 = QuantumRegister(4, 'b20')
c0 = QuantumRegister(5, 'c0')
c1 = QuantumRegister(5, 'c1')
comp0 = QuantumRegister(1, 'comp0')
new_rem0 = QuantumRegister(4, 'new_rem0')
temp0 = QuantumRegister(1, 'temp0')
temp1 = QuantumRegister(1, 'temp1')
temp2 = QuantumRegister(1, 'temp2')
shifted_rem1 = QuantumRegister(4, 'shifted_rem1')
diff1 = QuantumRegister(4, 'diff1')
inv1 = QuantumRegister(4, 'inv1')
one1 = QuantumRegister(4, 'one1')
b21 = QuantumRegister(4, 'b21')
c2 = QuantumRegister(5, 'c2')
c3 = QuantumRegister(5, 'c3')
comp1 = QuantumRegister(1, 'comp1')
new_rem1 = QuantumRegister(4, 'new_rem1')
temp3 = QuantumRegister(1, 'temp3')
temp4 = QuantumRegister(1, 'temp4')
temp5 = QuantumRegister(1, 'temp5')
shifted_rem2 = QuantumRegister(4, 'shifted_rem2')
diff2 = QuantumRegister(4, 'diff2')
inv2 = QuantumRegister(4, 'inv2')
one2 = QuantumRegister(4, 'one2')
b22 = QuantumRegister(4, 'b22')
c4 = QuantumRegister(5, 'c4')
c5 = QuantumRegister(5, 'c5')
comp2 = QuantumRegister(1, 'comp2')
new_rem2 = QuantumRegister(4, 'new_rem2')
temp6 = QuantumRegister(1, 'temp6')
temp7 = QuantumRegister(1, 'temp7')
temp8 = QuantumRegister(1, 'temp8')
shifted_rem3 = QuantumRegister(4, 'shifted_rem3')
diff3 = QuantumRegister(4, 'diff3')
inv3 = QuantumRegister(4, 'inv3')
one3 = QuantumRegister(4, 'one3')
b23 = QuantumRegister(4, 'b23')
c6 = QuantumRegister(5, 'c6')
c7 = QuantumRegister(5, 'c7')
comp3 = QuantumRegister(1, 'comp3')
new_rem3 = QuantumRegister(4, 'new_rem3')
temp9 = QuantumRegister(1, 'temp9')
temp10 = QuantumRegister(1, 'temp10')
temp11 = QuantumRegister(1, 'temp11')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, quot0, rem0, shifted_rem0, diff0, inv0, one0, b20, c0, c1, comp0, new_rem0, temp0, temp1, temp2, shifted_rem1, diff1, inv1, one1, b21, c2, c3, comp1, new_rem1, temp3, temp4, temp5, shifted_rem2, diff2, inv2, one2, b22, c4, c5, comp2, new_rem2, temp6, temp7, temp8, shifted_rem3, diff3, inv3, one3, b23, c6, c7, comp3, new_rem3, temp9, temp10, temp11, t0)

# Function: main
initialize_register(qc, q0, 4, 4)
initialize_register(qc, q1, 2, 4)
initialize_register(qc, quot0, 0, 4)
initialize_register(qc, rem0, 0, 4)
qc.cx(rem0[0], shifted_rem0[1])
qc.cx(rem0[1], shifted_rem0[2])
qc.cx(rem0[2], shifted_rem0[3])
qc.cx(q0[3], shifted_rem0[0])
qc.cx(q1[0], inv0[0])
qc.x(inv0[0])
qc.cx(q1[1], inv0[1])
qc.x(inv0[1])
qc.cx(q1[2], inv0[2])
qc.x(inv0[2])
qc.cx(q1[3], inv0[3])
qc.x(inv0[3])
initialize_register(qc, one0, 1, 4)
qc.cx(inv0[0], b20[0])
qc.cx(one0[0], b20[0])
qc.ccx(inv0[0], one0[0], c0[1])
qc.cx(inv0[1], b20[1])
qc.cx(one0[1], b20[1])
qc.ccx(inv0[1], one0[1], c0[2])
qc.ccx(b20[1], c0[1], c0[2])
qc.cx(c0[1], b20[1])
qc.cx(inv0[2], b20[2])
qc.cx(one0[2], b20[2])
qc.ccx(inv0[2], one0[2], c0[3])
qc.ccx(b20[2], c0[2], c0[3])
qc.cx(c0[2], b20[2])
qc.cx(inv0[3], b20[3])
qc.cx(one0[3], b20[3])
qc.ccx(inv0[3], one0[3], c0[4])
qc.ccx(b20[3], c0[3], c0[4])
qc.cx(c0[3], b20[3])
qc.cx(shifted_rem0[0], diff0[0])
qc.cx(b20[0], diff0[0])
qc.ccx(shifted_rem0[0], b20[0], c1[1])
qc.cx(shifted_rem0[1], diff0[1])
qc.cx(b20[1], diff0[1])
qc.ccx(shifted_rem0[1], b20[1], c1[2])
qc.ccx(diff0[1], c1[1], c1[2])
qc.cx(c1[1], diff0[1])
qc.cx(shifted_rem0[2], diff0[2])
qc.cx(b20[2], diff0[2])
qc.ccx(shifted_rem0[2], b20[2], c1[3])
qc.ccx(diff0[2], c1[2], c1[3])
qc.cx(c1[2], diff0[2])
qc.cx(shifted_rem0[3], diff0[3])
qc.cx(b20[3], diff0[3])
qc.ccx(shifted_rem0[3], b20[3], c1[4])
qc.ccx(diff0[3], c1[3], c1[4])
qc.cx(c1[3], diff0[3])
qc.cx(diff0[3], comp0[0])
qc.x(comp0[0])
qc.cx(comp0[0], quot0[3])
qc.cx(shifted_rem0[0], new_rem0[0])
qc.cx(shifted_rem0[1], new_rem0[1])
qc.cx(shifted_rem0[2], new_rem0[2])
qc.cx(shifted_rem0[3], new_rem0[3])
qc.ccx(comp0[0], diff0[0], temp0[0])
qc.cx(temp0[0], new_rem0[0])
qc.ccx(comp0[0], diff0[1], temp1[0])
qc.cx(temp1[0], new_rem0[1])
qc.ccx(comp0[0], diff0[2], temp2[0])
qc.cx(temp2[0], new_rem0[2])
qc.cx(new_rem0[0], shifted_rem1[1])
qc.cx(new_rem0[1], shifted_rem1[2])
qc.cx(new_rem0[2], shifted_rem1[3])
qc.cx(q0[2], shifted_rem1[0])
qc.cx(q1[0], inv1[0])
qc.x(inv1[0])
qc.cx(q1[1], inv1[1])
qc.x(inv1[1])
qc.cx(q1[2], inv1[2])
qc.x(inv1[2])
qc.cx(q1[3], inv1[3])
qc.x(inv1[3])
initialize_register(qc, one1, 1, 4)
qc.cx(inv1[0], b21[0])
qc.cx(one1[0], b21[0])
qc.ccx(inv1[0], one1[0], c2[1])
qc.cx(inv1[1], b21[1])
qc.cx(one1[1], b21[1])
qc.ccx(inv1[1], one1[1], c2[2])
qc.ccx(b21[1], c2[1], c2[2])
qc.cx(c2[1], b21[1])
qc.cx(inv1[2], b21[2])
qc.cx(one1[2], b21[2])
qc.ccx(inv1[2], one1[2], c2[3])
qc.ccx(b21[2], c2[2], c2[3])
qc.cx(c2[2], b21[2])
qc.cx(inv1[3], b21[3])
qc.cx(one1[3], b21[3])
qc.ccx(inv1[3], one1[3], c2[4])
qc.ccx(b21[3], c2[3], c2[4])
qc.cx(c2[3], b21[3])
qc.cx(shifted_rem1[0], diff1[0])
qc.cx(b21[0], diff1[0])
qc.ccx(shifted_rem1[0], b21[0], c3[1])
qc.cx(shifted_rem1[1], diff1[1])
qc.cx(b21[1], diff1[1])
qc.ccx(shifted_rem1[1], b21[1], c3[2])
qc.ccx(diff1[1], c3[1], c3[2])
qc.cx(c3[1], diff1[1])
qc.cx(shifted_rem1[2], diff1[2])
qc.cx(b21[2], diff1[2])
qc.ccx(shifted_rem1[2], b21[2], c3[3])
qc.ccx(diff1[2], c3[2], c3[3])
qc.cx(c3[2], diff1[2])
qc.cx(shifted_rem1[3], diff1[3])
qc.cx(b21[3], diff1[3])
qc.ccx(shifted_rem1[3], b21[3], c3[4])
qc.ccx(diff1[3], c3[3], c3[4])
qc.cx(c3[3], diff1[3])
qc.cx(diff1[3], comp1[0])
qc.x(comp1[0])
qc.cx(comp1[0], quot0[2])
qc.cx(shifted_rem1[0], new_rem1[0])
qc.cx(shifted_rem1[1], new_rem1[1])
qc.cx(shifted_rem1[2], new_rem1[2])
qc.cx(shifted_rem1[3], new_rem1[3])
qc.ccx(comp1[0], diff1[0], temp3[0])
qc.cx(temp3[0], new_rem1[0])
qc.ccx(comp1[0], diff1[1], temp4[0])
qc.cx(temp4[0], new_rem1[1])
qc.ccx(comp1[0], diff1[2], temp5[0])
qc.cx(temp5[0], new_rem1[2])
qc.cx(new_rem1[0], shifted_rem2[1])
qc.cx(new_rem1[1], shifted_rem2[2])
qc.cx(new_rem1[2], shifted_rem2[3])
qc.cx(q0[1], shifted_rem2[0])
qc.cx(q1[0], inv2[0])
qc.x(inv2[0])
qc.cx(q1[1], inv2[1])
qc.x(inv2[1])
qc.cx(q1[2], inv2[2])
qc.x(inv2[2])
qc.cx(q1[3], inv2[3])
qc.x(inv2[3])
initialize_register(qc, one2, 1, 4)
qc.cx(inv2[0], b22[0])
qc.cx(one2[0], b22[0])
qc.ccx(inv2[0], one2[0], c4[1])
qc.cx(inv2[1], b22[1])
qc.cx(one2[1], b22[1])
qc.ccx(inv2[1], one2[1], c4[2])
qc.ccx(b22[1], c4[1], c4[2])
qc.cx(c4[1], b22[1])
qc.cx(inv2[2], b22[2])
qc.cx(one2[2], b22[2])
qc.ccx(inv2[2], one2[2], c4[3])
qc.ccx(b22[2], c4[2], c4[3])
qc.cx(c4[2], b22[2])
qc.cx(inv2[3], b22[3])
qc.cx(one2[3], b22[3])
qc.ccx(inv2[3], one2[3], c4[4])
qc.ccx(b22[3], c4[3], c4[4])
qc.cx(c4[3], b22[3])
qc.cx(shifted_rem2[0], diff2[0])
qc.cx(b22[0], diff2[0])
qc.ccx(shifted_rem2[0], b22[0], c5[1])
qc.cx(shifted_rem2[1], diff2[1])
qc.cx(b22[1], diff2[1])
qc.ccx(shifted_rem2[1], b22[1], c5[2])
qc.ccx(diff2[1], c5[1], c5[2])
qc.cx(c5[1], diff2[1])
qc.cx(shifted_rem2[2], diff2[2])
qc.cx(b22[2], diff2[2])
qc.ccx(shifted_rem2[2], b22[2], c5[3])
qc.ccx(diff2[2], c5[2], c5[3])
qc.cx(c5[2], diff2[2])
qc.cx(shifted_rem2[3], diff2[3])
qc.cx(b22[3], diff2[3])
qc.ccx(shifted_rem2[3], b22[3], c5[4])
qc.ccx(diff2[3], c5[3], c5[4])
qc.cx(c5[3], diff2[3])
qc.cx(diff2[3], comp2[0])
qc.x(comp2[0])
qc.cx(comp2[0], quot0[1])
qc.cx(shifted_rem2[0], new_rem2[0])
qc.cx(shifted_rem2[1], new_rem2[1])
qc.cx(shifted_rem2[2], new_rem2[2])
qc.cx(shifted_rem2[3], new_rem2[3])
qc.ccx(comp2[0], diff2[0], temp6[0])
qc.cx(temp6[0], new_rem2[0])
qc.ccx(comp2[0], diff2[1], temp7[0])
qc.cx(temp7[0], new_rem2[1])
qc.ccx(comp2[0], diff2[2], temp8[0])
qc.cx(temp8[0], new_rem2[2])
qc.cx(new_rem2[0], shifted_rem3[1])
qc.cx(new_rem2[1], shifted_rem3[2])
qc.cx(new_rem2[2], shifted_rem3[3])
qc.cx(q0[0], shifted_rem3[0])
qc.cx(q1[0], inv3[0])
qc.x(inv3[0])
qc.cx(q1[1], inv3[1])
qc.x(inv3[1])
qc.cx(q1[2], inv3[2])
qc.x(inv3[2])
qc.cx(q1[3], inv3[3])
qc.x(inv3[3])
initialize_register(qc, one3, 1, 4)
qc.cx(inv3[0], b23[0])
qc.cx(one3[0], b23[0])
qc.ccx(inv3[0], one3[0], c6[1])
qc.cx(inv3[1], b23[1])
qc.cx(one3[1], b23[1])
qc.ccx(inv3[1], one3[1], c6[2])
qc.ccx(b23[1], c6[1], c6[2])
qc.cx(c6[1], b23[1])
qc.cx(inv3[2], b23[2])
qc.cx(one3[2], b23[2])
qc.ccx(inv3[2], one3[2], c6[3])
qc.ccx(b23[2], c6[2], c6[3])
qc.cx(c6[2], b23[2])
qc.cx(inv3[3], b23[3])
qc.cx(one3[3], b23[3])
qc.ccx(inv3[3], one3[3], c6[4])
qc.ccx(b23[3], c6[3], c6[4])
qc.cx(c6[3], b23[3])
qc.cx(shifted_rem3[0], diff3[0])
qc.cx(b23[0], diff3[0])
qc.ccx(shifted_rem3[0], b23[0], c7[1])
qc.cx(shifted_rem3[1], diff3[1])
qc.cx(b23[1], diff3[1])
qc.ccx(shifted_rem3[1], b23[1], c7[2])
qc.ccx(diff3[1], c7[1], c7[2])
qc.cx(c7[1], diff3[1])
qc.cx(shifted_rem3[2], diff3[2])
qc.cx(b23[2], diff3[2])
qc.ccx(shifted_rem3[2], b23[2], c7[3])
qc.ccx(diff3[2], c7[2], c7[3])
qc.cx(c7[2], diff3[2])
qc.cx(shifted_rem3[3], diff3[3])
qc.cx(b23[3], diff3[3])
qc.ccx(shifted_rem3[3], b23[3], c7[4])
qc.ccx(diff3[3], c7[3], c7[4])
qc.cx(c7[3], diff3[3])
qc.cx(diff3[3], comp3[0])
qc.x(comp3[0])
qc.cx(comp3[0], quot0[0])
qc.cx(shifted_rem3[0], new_rem3[0])
qc.cx(shifted_rem3[1], new_rem3[1])
qc.cx(shifted_rem3[2], new_rem3[2])
qc.cx(shifted_rem3[3], new_rem3[3])
qc.ccx(comp3[0], diff3[0], temp9[0])
qc.cx(temp9[0], new_rem3[0])
qc.ccx(comp3[0], diff3[1], temp10[0])
qc.cx(temp10[0], new_rem3[1])
qc.ccx(comp3[0], diff3[2], temp11[0])
qc.cx(temp11[0], new_rem3[2])
qc.cx(quot0[0], q3[0])
qc.cx(quot0[1], q3[1])
qc.cx(quot0[2], q3[2])
qc.cx(quot0[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")
# Out:
# Measurement result: ClassicalRegister(4, 't0')
#
# Measurement results: {'0011': 1024}
# Circuit output: 3 (binary: 0011)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
quot0 = QuantumRegister(4, 'quot0')
rem0 = QuantumRegister(4, 'rem0')
srem0 = QuantumRegister(4, 'srem0')
diff0 = QuantumRegister(4, 'diff0')
inv0 = QuantumRegister(4, 'inv0')
one0 = QuantumRegister(4, 'one0')
b20 = QuantumRegister(4, 'b20')
c0 = QuantumRegister(5, 'c0')
c1 = QuantumRegister(5, 'c1')
geq0 = QuantumRegister(1, 'geq0')
nrem0 = QuantumRegister(4, 'nrem0')
temp0 = QuantumRegister(1, 'temp0')
temp1 = QuantumRegister(1, 'temp1')
temp2 = QuantumRegister(1, 'temp2')
srem1 = QuantumRegister(4, 'srem1')
diff1 = QuantumRegister(4, 'diff1')
inv1 = QuantumRegister(4, 'inv1')
one1 = QuantumRegister(4, 'one1')
b21 = QuantumRegister(4, 'b21')
c2 = QuantumRegister(5, 'c2')
c3 = QuantumRegister(5, 'c3')
geq1 = QuantumRegister(1, 'geq1')
nrem1 = QuantumRegister(4, 'nrem1')
temp3 = QuantumRegister(1, 'temp3')
temp4 = QuantumRegister(1, 'temp4')
temp5 = QuantumRegister(1, 'temp5')
srem2 = QuantumRegister(4, 'srem2')
diff2 = QuantumRegister(4, 'diff2')
inv2 = QuantumRegister(4, 'inv2')
one2 = QuantumRegister(4, 'one2')
b22 = QuantumRegister(4, 'b22')
c4 = QuantumRegister(5, 'c4')
c5 = QuantumRegister(5, 'c5')
geq2 = QuantumRegister(1, 'geq2')
nrem2 = QuantumRegister(4, 'nrem2')
temp6 = QuantumRegister(1, 'temp6')
temp7 = QuantumRegister(1, 'temp7')
temp8 = QuantumRegister(1, 'temp8')
srem3 = QuantumRegister(4, 'srem3')
diff3 = QuantumRegister(4, 'diff3')
inv3 = QuantumRegister(4, 'inv3')
one3 = QuantumRegister(4, 'one3')
b23 = QuantumRegister(4, 'b23')
c6 = QuantumRegister(5, 'c6')
c7 = QuantumRegister(5, 'c7')
geq3 = QuantumRegister(1, 'geq3')
nrem3 = QuantumRegister(4, 'nrem3')
temp9 = QuantumRegister(1, 'temp9')
temp10 = QuantumRegister(1, 'temp10')
temp11 = QuantumRegister(1, 'temp11')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, quot0, rem0, srem0, diff0, inv0, one0, b20, c0, c1, geq0, nrem0, temp0, temp1, temp2, srem1, diff1, inv1, one1, b21, c2, c3, geq1, nrem1, temp3, temp4, temp5, srem2, diff2, inv2, one2, b22, c4, c5, geq2, nrem2, temp6, temp7, temp8, srem3, diff3, inv3, one3, b23, c6, c7, geq3, nrem3, temp9, temp10, temp11, t0)

# Function: main
initialize_register(qc, q0, 4, 4)
initialize_register(qc, q1, 2, 4)
initialize_register(qc, quot0, 0, 4)
initialize_register(qc, rem0, 0, 4)
initialize_register(qc, srem0, 0, 4)
qc.cx(rem0[0], srem0[1])
qc.cx(rem0[1], srem0[2])
qc.cx(rem0[2], srem0[3])
qc.cx(q0[3], srem0[0])
qc.cx(q1[0], inv0[0])
qc.x(inv0[0])
qc.cx(q1[1], inv0[1])
qc.x(inv0[1])
qc.cx(q1[2], inv0[2])
qc.x(inv0[2])
qc.cx(q1[3], inv0[3])
qc.x(inv0[3])
initialize_register(qc, one0, 1, 4)
qc.cx(inv0[0], b20[0])
qc.cx(one0[0], b20[0])
qc.ccx(inv0[0], one0[0], c0[1])
qc.cx(inv0[1], b20[1])
qc.cx(one0[1], b20[1])
qc.ccx(inv0[1], one0[1], c0[2])
qc.ccx(b20[1], c0[1], c0[2])
qc.cx(c0[1], b20[1])
qc.cx(inv0[2], b20[2])
qc.cx(one0[2], b20[2])
qc.ccx(inv0[2], one0[2], c0[3])
qc.ccx(b20[2], c0[2], c0[3])
qc.cx(c0[2], b20[2])
qc.cx(inv0[3], b20[3])
qc.cx(one0[3], b20[3])
qc.ccx(inv0[3], one0[3], c0[4])
qc.ccx(b20[3], c0[3], c0[4])
qc.cx(c0[3], b20[3])
qc.cx(srem0[0], diff0[0])
qc.cx(b20[0], diff0[0])
qc.ccx(srem0[0], b20[0], c1[1])
qc.cx(srem0[1], diff0[1])
qc.cx(b20[1], diff0[1])
qc.ccx(srem0[1], b20[1], c1[2])
qc.ccx(diff0[1], c1[1], c1[2])
qc.cx(c1[1], diff0[1])
qc.cx(srem0[2], diff0[2])
qc.cx(b20[2], diff0[2])
qc.ccx(srem0[2], b20[2], c1[3])
qc.ccx(diff0[2], c1[2], c1[3])
qc.cx(c1[2], diff0[2])
qc.cx(srem0[3], diff0[3])
qc.cx(b20[3], diff0[3])
qc.ccx(srem0[3], b20[3], c1[4])
qc.ccx(diff0[3], c1[3], c1[4])
qc.cx(c1[3], diff0[3])
qc.cx(diff0[3], geq0[0])
qc.x(geq0[0])
qc.cx(geq0[0], quot0[3])
qc.cx(srem0[0], nrem0[0])
qc.cx(srem0[1], nrem0[1])
qc.cx(srem0[2], nrem0[2])
qc.cx(srem0[3], nrem0[3])
qc.ccx(geq0[0], diff0[0], temp0[0])
qc.cx(temp0[0], nrem0[0])
qc.ccx(geq0[0], diff0[1], temp1[0])
qc.cx(temp1[0], nrem0[1])
qc.ccx(geq0[0], diff0[2], temp2[0])
qc.cx(temp2[0], nrem0[2])
initialize_register(qc, srem1, 0, 4)
qc.cx(nrem0[0], srem1[1])
qc.cx(nrem0[1], srem1[2])
qc.cx(nrem0[2], srem1[3])
qc.cx(q0[2], srem1[0])
qc.cx(q1[0], inv1[0])
qc.x(inv1[0])
qc.cx(q1[1], inv1[1])
qc.x(inv1[1])
qc.cx(q1[2], inv1[2])
qc.x(inv1[2])
qc.cx(q1[3], inv1[3])
qc.x(inv1[3])
initialize_register(qc, one1, 1, 4)
qc.cx(inv1[0], b21[0])
qc.cx(one1[0], b21[0])
qc.ccx(inv1[0], one1[0], c2[1])
qc.cx(inv1[1], b21[1])
qc.cx(one1[1], b21[1])
qc.ccx(inv1[1], one1[1], c2[2])
qc.ccx(b21[1], c2[1], c2[2])
qc.cx(c2[1], b21[1])
qc.cx(inv1[2], b21[2])
qc.cx(one1[2], b21[2])
qc.ccx(inv1[2], one1[2], c2[3])
qc.ccx(b21[2], c2[2], c2[3])
qc.cx(c2[2], b21[2])
qc.cx(inv1[3], b21[3])
qc.cx(one1[3], b21[3])
qc.ccx(inv1[3], one1[3], c2[4])
qc.ccx(b21[3], c2[3], c2[4])
qc.cx(c2[3], b21[3])
qc.cx(srem1[0], diff1[0])
qc.cx(b21[0], diff1[0])
qc.ccx(srem1[0], b21[0], c3[1])
qc.cx(srem1[1], diff1[1])
qc.cx(b21[1], diff1[1])
qc.ccx(srem1[1], b21[1], c3[2])
qc.ccx(diff1[1], c3[1], c3[2])
qc.cx(c3[1], diff1[1])
qc.cx(srem1[2], diff1[2])
qc.cx(b21[2], diff1[2])
qc.ccx(srem1[2], b21[2], c3[3])
qc.ccx(diff1[2], c3[2], c3[3])
qc.cx(c3[2], diff1[2])
qc.cx(srem1[3], diff1[3])
qc.cx(b21[3], diff1[3])
qc.ccx(srem1[3], b21[3], c3[4])
qc.ccx(diff1[3], c3[3], c3[4])
qc.cx(c3[3], diff1[3])
qc.cx(diff1[3], geq1[0])
qc.x(geq1[0])
qc.cx(geq1[0], quot0[2])
qc.cx(srem1[0], nrem1[0])
qc.cx(srem1[1], nrem1[1])
qc.cx(srem1[2], nrem1[2])
qc.cx(srem1[3], nrem1[3])
qc.ccx(geq1[0], diff1[0], temp3[0])
qc.cx(temp3[0], nrem1[0])
qc.ccx(geq1[0], diff1[1], temp4[0])
qc.cx(temp4[0], nrem1[1])
qc.ccx(geq1[0], diff1[2], temp5[0])
qc.cx(temp5[0], nrem1[2])
initialize_register(qc, srem2, 0, 4)
qc.cx(nrem1[0], srem2[1])
qc.cx(nrem1[1], srem2[2])
qc.cx(nrem1[2], srem2[3])
qc.cx(q0[1], srem2[0])
qc.cx(q1[0], inv2[0])
qc.x(inv2[0])
qc.cx(q1[1], inv2[1])
qc.x(inv2[1])
qc.cx(q1[2], inv2[2])
qc.x(inv2[2])
qc.cx(q1[3], inv2[3])
qc.x(inv2[3])
initialize_register(qc, one2, 1, 4)
qc.cx(inv2[0], b22[0])
qc.cx(one2[0], b22[0])
qc.ccx(inv2[0], one2[0], c4[1])
qc.cx(inv2[1], b22[1])
qc.cx(one2[1], b22[1])
qc.ccx(inv2[1], one2[1], c4[2])
qc.ccx(b22[1], c4[1], c4[2])
qc.cx(c4[1], b22[1])
qc.cx(inv2[2], b22[2])
qc.cx(one2[2], b22[2])
qc.ccx(inv2[2], one2[2], c4[3])
qc.ccx(b22[2], c4[2], c4[3])
qc.cx(c4[2], b22[2])
qc.cx(inv2[3], b22[3])
qc.cx(one2[3], b22[3])
qc.ccx(inv2[3], one2[3], c4[4])
qc.ccx(b22[3], c4[3], c4[4])
qc.cx(c4[3], b22[3])
qc.cx(srem2[0], diff2[0])
qc.cx(b22[0], diff2[0])
qc.ccx(srem2[0], b22[0], c5[1])
qc.cx(srem2[1], diff2[1])
qc.cx(b22[1], diff2[1])
qc.ccx(srem2[1], b22[1], c5[2])
qc.ccx(diff2[1], c5[1], c5[2])
qc.cx(c5[1], diff2[1])
qc.cx(srem2[2], diff2[2])
qc.cx(b22[2], diff2[2])
qc.ccx(srem2[2], b22[2], c5[3])
qc.ccx(diff2[2], c5[2], c5[3])
qc.cx(c5[2], diff2[2])
qc.cx(srem2[3], diff2[3])
qc.cx(b22[3], diff2[3])
qc.ccx(srem2[3], b22[3], c5[4])
qc.ccx(diff2[3], c5[3], c5[4])
qc.cx(c5[3], diff2[3])
qc.cx(diff2[3], geq2[0])
qc.x(geq2[0])
qc.cx(geq2[0], quot0[1])
qc.cx(srem2[0], nrem2[0])
qc.cx(srem2[1], nrem2[1])
qc.cx(srem2[2], nrem2[2])
qc.cx(srem2[3], nrem2[3])
qc.ccx(geq2[0], diff2[0], temp6[0])
qc.cx(temp6[0], nrem2[0])
qc.ccx(geq2[0], diff2[1], temp7[0])
qc.cx(temp7[0], nrem2[1])
qc.ccx(geq2[0], diff2[2], temp8[0])
qc.cx(temp8[0], nrem2[2])
initialize_register(qc, srem3, 0, 4)
qc.cx(nrem2[0], srem3[1])
qc.cx(nrem2[1], srem3[2])
qc.cx(nrem2[2], srem3[3])
qc.cx(q0[0], srem3[0])
qc.cx(q1[0], inv3[0])
qc.x(inv3[0])
qc.cx(q1[1], inv3[1])
qc.x(inv3[1])
qc.cx(q1[2], inv3[2])
qc.x(inv3[2])
qc.cx(q1[3], inv3[3])
qc.x(inv3[3])
initialize_register(qc, one3, 1, 4)
qc.cx(inv3[0], b23[0])
qc.cx(one3[0], b23[0])
qc.ccx(inv3[0], one3[0], c6[1])
qc.cx(inv3[1], b23[1])
qc.cx(one3[1], b23[1])
qc.ccx(inv3[1], one3[1], c6[2])
qc.ccx(b23[1], c6[1], c6[2])
qc.cx(c6[1], b23[1])
qc.cx(inv3[2], b23[2])
qc.cx(one3[2], b23[2])
qc.ccx(inv3[2], one3[2], c6[3])
qc.ccx(b23[2], c6[2], c6[3])
qc.cx(c6[2], b23[2])
qc.cx(inv3[3], b23[3])
qc.cx(one3[3], b23[3])
qc.ccx(inv3[3], one3[3], c6[4])
qc.ccx(b23[3], c6[3], c6[4])
qc.cx(c6[3], b23[3])
qc.cx(srem3[0], diff3[0])
qc.cx(b23[0], diff3[0])
qc.ccx(srem3[0], b23[0], c7[1])
qc.cx(srem3[1], diff3[1])
qc.cx(b23[1], diff3[1])
qc.ccx(srem3[1], b23[1], c7[2])
qc.ccx(diff3[1], c7[1], c7[2])
qc.cx(c7[1], diff3[1])
qc.cx(srem3[2], diff3[2])
qc.cx(b23[2], diff3[2])
qc.ccx(srem3[2], b23[2], c7[3])
qc.ccx(diff3[2], c7[2], c7[3])
qc.cx(c7[2], diff3[2])
qc.cx(srem3[3], diff3[3])
qc.cx(b23[3], diff3[3])
qc.ccx(srem3[3], b23[3], c7[4])
qc.ccx(diff3[3], c7[3], c7[4])
qc.cx(c7[3], diff3[3])
qc.cx(diff3[3], geq3[0])
qc.x(geq3[0])
qc.cx(geq3[0], quot0[0])
qc.cx(srem3[0], nrem3[0])
qc.cx(srem3[1], nrem3[1])
qc.cx(srem3[2], nrem3[2])
qc.cx(srem3[3], nrem3[3])
qc.ccx(geq3[0], diff3[0], temp9[0])
qc.cx(temp9[0], nrem3[0])
qc.ccx(geq3[0], diff3[1], temp10[0])
qc.cx(temp10[0], nrem3[1])
qc.ccx(geq3[0], diff3[2], temp11[0])
qc.cx(temp11[0], nrem3[2])
qc.cx(quot0[0], q3[0])
qc.cx(quot0[1], q3[1])
qc.cx(quot0[2], q3[2])
qc.cx(quot0[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")
# Out:
# Measurement result: ClassicalRegister(4, 't0')
#
# Measurement results: {'0011': 1024}
# Circuit output: 3 (binary: 0011)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
# Helper to initialize a quantum register to a classical value
def initialize_register(qc, qreg, value, num_bits):
    # This is a placeholder: in practice, you need a circuit to load a binary number
    # Here we assume the register is already in state |0> and then use X gates to set bits.

    # IMPORTANT FIX: Reverse the bit string so qubit[0] is the LSB
    bin_val = format(value, '0{}b'.format(num_bits))[::-1]
    for i, bit in enumerate(bin_val):
        if bit == '1':
            qc.x(qreg[i])


q0 = QuantumRegister(4, 'q0')
q1 = QuantumRegister(4, 'q1')
q2 = QuantumRegister(4, 'q2')
q3 = QuantumRegister(4, 'q3')
quot0 = QuantumRegister(4, 'quot0')
rem0 = QuantumRegister(4, 'rem0')
srem0 = QuantumRegister(4, 'srem0')
diff0 = QuantumRegister(4, 'diff0')
inv0 = QuantumRegister(4, 'inv0')
one0 = QuantumRegister(4, 'one0')
b20 = QuantumRegister(4, 'b20')
c0 = QuantumRegister(5, 'c0')
c1 = QuantumRegister(5, 'c1')
geq0 = QuantumRegister(1, 'geq0')
nrem0 = QuantumRegister(4, 'nrem0')
temp0 = QuantumRegister(1, 'temp0')
temp1 = QuantumRegister(1, 'temp1')
temp2 = QuantumRegister(1, 'temp2')
srem1 = QuantumRegister(4, 'srem1')
diff1 = QuantumRegister(4, 'diff1')
inv1 = QuantumRegister(4, 'inv1')
one1 = QuantumRegister(4, 'one1')
b21 = QuantumRegister(4, 'b21')
c2 = QuantumRegister(5, 'c2')
c3 = QuantumRegister(5, 'c3')
geq1 = QuantumRegister(1, 'geq1')
nrem1 = QuantumRegister(4, 'nrem1')
temp3 = QuantumRegister(1, 'temp3')
temp4 = QuantumRegister(1, 'temp4')
temp5 = QuantumRegister(1, 'temp5')
srem2 = QuantumRegister(4, 'srem2')
diff2 = QuantumRegister(4, 'diff2')
inv2 = QuantumRegister(4, 'inv2')
one2 = QuantumRegister(4, 'one2')
b22 = QuantumRegister(4, 'b22')
c4 = QuantumRegister(5, 'c4')
c5 = QuantumRegister(5, 'c5')
geq2 = QuantumRegister(1, 'geq2')
nrem2 = QuantumRegister(4, 'nrem2')
temp6 = QuantumRegister(1, 'temp6')
temp7 = QuantumRegister(1, 'temp7')
temp8 = QuantumRegister(1, 'temp8')
srem3 = QuantumRegister(4, 'srem3')
diff3 = QuantumRegister(4, 'diff3')
inv3 = QuantumRegister(4, 'inv3')
one3 = QuantumRegister(4, 'one3')
b23 = QuantumRegister(4, 'b23')
c6 = QuantumRegister(5, 'c6')
c7 = QuantumRegister(5, 'c7')
geq3 = QuantumRegister(1, 'geq3')
nrem3 = QuantumRegister(4, 'nrem3')
temp9 = QuantumRegister(1, 'temp9')
temp10 = QuantumRegister(1, 'temp10')
temp11 = QuantumRegister(1, 'temp11')
t0 = ClassicalRegister(4, 't0')
qc = QuantumCircuit(q0, q1, q2, q3, quot0, rem0, srem0, diff0, inv0, one0, b20, c0, c1, geq0, nrem0, temp0, temp1, temp2, srem1, diff1, inv1, one1, b21, c2, c3, geq1, nrem1, temp3, temp4, temp5, srem2, diff2, inv2, one2, b22, c4, c5, geq2, nrem2, temp6, temp7, temp8, srem3, diff3, inv3, one3, b23, c6, c7, geq3, nrem3, temp9, temp10, temp11, t0)

# Function: main
initialize_register(qc, q0, 2, 4)
initialize_register(qc, q1, 2, 4)
initialize_register(qc, quot0, 0, 4)
initialize_register(qc, rem0, 0, 4)
initialize_register(qc, srem0, 0, 4)
qc.cx(rem0[2], srem0[3])
qc.cx(rem0[1], srem0[2])
qc.cx(rem0[0], srem0[1])
qc.cx(q0[3], srem0[0])
qc.cx(q1[0], inv0[0])
qc.x(inv0[0])
qc.cx(q1[1], inv0[1])
qc.x(inv0[1])
qc.cx(q1[2], inv0[2])
qc.x(inv0[2])
qc.cx(q1[3], inv0[3])
qc.x(inv0[3])
initialize_register(qc, one0, 1, 4)
qc.cx(inv0[0], b20[0])
qc.cx(one0[0], b20[0])
qc.ccx(inv0[0], one0[0], c0[1])
qc.cx(inv0[1], b20[1])
qc.cx(one0[1], b20[1])
qc.ccx(inv0[1], one0[1], c0[2])
qc.ccx(b20[1], c0[1], c0[2])
qc.cx(c0[1], b20[1])
qc.cx(inv0[2], b20[2])
qc.cx(one0[2], b20[2])
qc.ccx(inv0[2], one0[2], c0[3])
qc.ccx(b20[2], c0[2], c0[3])
qc.cx(c0[2], b20[2])
qc.cx(inv0[3], b20[3])
qc.cx(one0[3], b20[3])
qc.ccx(inv0[3], one0[3], c0[4])
qc.ccx(b20[3], c0[3], c0[4])
qc.cx(c0[3], b20[3])
qc.cx(srem0[0], diff0[0])
qc.cx(b20[0], diff0[0])
qc.ccx(srem0[0], b20[0], c1[1])
qc.cx(srem0[1], diff0[1])
qc.cx(b20[1], diff0[1])
qc.ccx(srem0[1], b20[1], c1[2])
qc.ccx(diff0[1], c1[1], c1[2])
qc.cx(c1[1], diff0[1])
qc.cx(srem0[2], diff0[2])
qc.cx(b20[2], diff0[2])
qc.ccx(srem0[2], b20[2], c1[3])
qc.ccx(diff0[2], c1[2], c1[3])
qc.cx(c1[2], diff0[2])
qc.cx(srem0[3], diff0[3])
qc.cx(b20[3], diff0[3])
qc.ccx(srem0[3], b20[3], c1[4])
qc.ccx(diff0[3], c1[3], c1[4])
qc.cx(c1[3], diff0[3])
qc.cx(diff0[3], geq0[0])
qc.x(geq0[0])
qc.cx(geq0[0], quot0[3])
qc.cx(srem0[0], nrem0[0])
qc.cx(srem0[1], nrem0[1])
qc.cx(srem0[2], nrem0[2])
qc.cx(srem0[3], nrem0[3])
qc.ccx(geq0[0], diff0[0], temp0[0])
qc.cx(temp0[0], nrem0[0])
qc.ccx(geq0[0], diff0[1], temp1[0])
qc.cx(temp1[0], nrem0[1])
qc.ccx(geq0[0], diff0[2], temp2[0])
qc.cx(temp2[0], nrem0[2])
initialize_register(qc, srem1, 0, 4)
qc.cx(nrem0[2], srem1[3])
qc.cx(nrem0[1], srem1[2])
qc.cx(nrem0[0], srem1[1])
qc.cx(q0[2], srem1[0])
qc.cx(q1[0], inv1[0])
qc.x(inv1[0])
qc.cx(q1[1], inv1[1])
qc.x(inv1[1])
qc.cx(q1[2], inv1[2])
qc.x(inv1[2])
qc.cx(q1[3], inv1[3])
qc.x(inv1[3])
initialize_register(qc, one1, 1, 4)
qc.cx(inv1[0], b21[0])
qc.cx(one1[0], b21[0])
qc.ccx(inv1[0], one1[0], c2[1])
qc.cx(inv1[1], b21[1])
qc.cx(one1[1], b21[1])
qc.ccx(inv1[1], one1[1], c2[2])
qc.ccx(b21[1], c2[1], c2[2])
qc.cx(c2[1], b21[1])
qc.cx(inv1[2], b21[2])
qc.cx(one1[2], b21[2])
qc.ccx(inv1[2], one1[2], c2[3])
qc.ccx(b21[2], c2[2], c2[3])
qc.cx(c2[2], b21[2])
qc.cx(inv1[3], b21[3])
qc.cx(one1[3], b21[3])
qc.ccx(inv1[3], one1[3], c2[4])
qc.ccx(b21[3], c2[3], c2[4])
qc.cx(c2[3], b21[3])
qc.cx(srem1[0], diff1[0])
qc.cx(b21[0], diff1[0])
qc.ccx(srem1[0], b21[0], c3[1])
qc.cx(srem1[1], diff1[1])
qc.cx(b21[1], diff1[1])
qc.ccx(srem1[1], b21[1], c3[2])
qc.ccx(diff1[1], c3[1], c3[2])
qc.cx(c3[1], diff1[1])
qc.cx(srem1[2], diff1[2])
qc.cx(b21[2], diff1[2])
qc.ccx(srem1[2], b21[2], c3[3])
qc.ccx(diff1[2], c3[2], c3[3])
qc.cx(c3[2], diff1[2])
qc.cx(srem1[3], diff1[3])
qc.cx(b21[3], diff1[3])
qc.ccx(srem1[3], b21[3], c3[4])
qc.ccx(diff1[3], c3[3], c3[4])
qc.cx(c3[3], diff1[3])
qc.cx(diff1[3], geq1[0])
qc.x(geq1[0])
qc.cx(geq1[0], quot0[2])
qc.cx(srem1[0], nrem1[0])
qc.cx(srem1[1], nrem1[1])
qc.cx(srem1[2], nrem1[2])
qc.cx(srem1[3], nrem1[3])
qc.ccx(geq1[0], diff1[0], temp3[0])
qc.cx(temp3[0], nrem1[0])
qc.ccx(geq1[0], diff1[1], temp4[0])
qc.cx(temp4[0], nrem1[1])
qc.ccx(geq1[0], diff1[2], temp5[0])
qc.cx(temp5[0], nrem1[2])
initialize_register(qc, srem2, 0, 4)
qc.cx(nrem1[2], srem2[3])
qc.cx(nrem1[1], srem2[2])
qc.cx(nrem1[0], srem2[1])
qc.cx(q0[1], srem2[0])
qc.cx(q1[0], inv2[0])
qc.x(inv2[0])
qc.cx(q1[1], inv2[1])
qc.x(inv2[1])
qc.cx(q1[2], inv2[2])
qc.x(inv2[2])
qc.cx(q1[3], inv2[3])
qc.x(inv2[3])
initialize_register(qc, one2, 1, 4)
qc.cx(inv2[0], b22[0])
qc.cx(one2[0], b22[0])
qc.ccx(inv2[0], one2[0], c4[1])
qc.cx(inv2[1], b22[1])
qc.cx(one2[1], b22[1])
qc.ccx(inv2[1], one2[1], c4[2])
qc.ccx(b22[1], c4[1], c4[2])
qc.cx(c4[1], b22[1])
qc.cx(inv2[2], b22[2])
qc.cx(one2[2], b22[2])
qc.ccx(inv2[2], one2[2], c4[3])
qc.ccx(b22[2], c4[2], c4[3])
qc.cx(c4[2], b22[2])
qc.cx(inv2[3], b22[3])
qc.cx(one2[3], b22[3])
qc.ccx(inv2[3], one2[3], c4[4])
qc.ccx(b22[3], c4[3], c4[4])
qc.cx(c4[3], b22[3])
qc.cx(srem2[0], diff2[0])
qc.cx(b22[0], diff2[0])
qc.ccx(srem2[0], b22[0], c5[1])
qc.cx(srem2[1], diff2[1])
qc.cx(b22[1], diff2[1])
qc.ccx(srem2[1], b22[1], c5[2])
qc.ccx(diff2[1], c5[1], c5[2])
qc.cx(c5[1], diff2[1])
qc.cx(srem2[2], diff2[2])
qc.cx(b22[2], diff2[2])
qc.ccx(srem2[2], b22[2], c5[3])
qc.ccx(diff2[2], c5[2], c5[3])
qc.cx(c5[2], diff2[2])
qc.cx(srem2[3], diff2[3])
qc.cx(b22[3], diff2[3])
qc.ccx(srem2[3], b22[3], c5[4])
qc.ccx(diff2[3], c5[3], c5[4])
qc.cx(c5[3], diff2[3])
qc.cx(diff2[3], geq2[0])
qc.x(geq2[0])
qc.cx(geq2[0], quot0[1])
qc.cx(srem2[0], nrem2[0])
qc.cx(srem2[1], nrem2[1])
qc.cx(srem2[2], nrem2[2])
qc.cx(srem2[3], nrem2[3])
qc.ccx(geq2[0], diff2[0], temp6[0])
qc.cx(temp6[0], nrem2[0])
qc.ccx(geq2[0], diff2[1], temp7[0])
qc.cx(temp7[0], nrem2[1])
qc.ccx(geq2[0], diff2[2], temp8[0])
qc.cx(temp8[0], nrem2[2])
initialize_register(qc, srem3, 0, 4)
qc.cx(nrem2[2], srem3[3])
qc.cx(nrem2[1], srem3[2])
qc.cx(nrem2[0], srem3[1])
qc.cx(q0[0], srem3[0])
qc.cx(q1[0], inv3[0])
qc.x(inv3[0])
qc.cx(q1[1], inv3[1])
qc.x(inv3[1])
qc.cx(q1[2], inv3[2])
qc.x(inv3[2])
qc.cx(q1[3], inv3[3])
qc.x(inv3[3])
initialize_register(qc, one3, 1, 4)
qc.cx(inv3[0], b23[0])
qc.cx(one3[0], b23[0])
qc.ccx(inv3[0], one3[0], c6[1])
qc.cx(inv3[1], b23[1])
qc.cx(one3[1], b23[1])
qc.ccx(inv3[1], one3[1], c6[2])
qc.ccx(b23[1], c6[1], c6[2])
qc.cx(c6[1], b23[1])
qc.cx(inv3[2], b23[2])
qc.cx(one3[2], b23[2])
qc.ccx(inv3[2], one3[2], c6[3])
qc.ccx(b23[2], c6[2], c6[3])
qc.cx(c6[2], b23[2])
qc.cx(inv3[3], b23[3])
qc.cx(one3[3], b23[3])
qc.ccx(inv3[3], one3[3], c6[4])
qc.ccx(b23[3], c6[3], c6[4])
qc.cx(c6[3], b23[3])
qc.cx(srem3[0], diff3[0])
qc.cx(b23[0], diff3[0])
qc.ccx(srem3[0], b23[0], c7[1])
qc.cx(srem3[1], diff3[1])
qc.cx(b23[1], diff3[1])
qc.ccx(srem3[1], b23[1], c7[2])
qc.ccx(diff3[1], c7[1], c7[2])
qc.cx(c7[1], diff3[1])
qc.cx(srem3[2], diff3[2])
qc.cx(b23[2], diff3[2])
qc.ccx(srem3[2], b23[2], c7[3])
qc.ccx(diff3[2], c7[2], c7[3])
qc.cx(c7[2], diff3[2])
qc.cx(srem3[3], diff3[3])
qc.cx(b23[3], diff3[3])
qc.ccx(srem3[3], b23[3], c7[4])
qc.ccx(diff3[3], c7[3], c7[4])
qc.cx(c7[3], diff3[3])
qc.cx(diff3[3], geq3[0])
qc.x(geq3[0])
qc.cx(geq3[0], quot0[0])
qc.cx(srem3[0], nrem3[0])
qc.cx(srem3[1], nrem3[1])
qc.cx(srem3[2], nrem3[2])
qc.cx(srem3[3], nrem3[3])
qc.ccx(geq3[0], diff3[0], temp9[0])
qc.cx(temp9[0], nrem3[0])
qc.ccx(geq3[0], diff3[1], temp10[0])
qc.cx(temp10[0], nrem3[1])
qc.ccx(geq3[0], diff3[2], temp11[0])
qc.cx(temp11[0], nrem3[2])
qc.cx(quot0[0], q3[0])
qc.cx(quot0[1], q3[1])
qc.cx(quot0[2], q3[2])
qc.cx(quot0[3], q3[3])
qc.measure(q3, t0)
print('Measurement result:', t0)


# Use the automatic simulator to choose the best method
simulator = AerSimulator(method='matrix_product_state')
job = simulator.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print('\nMeasurement results:', counts)

# Uncomment to see circuit visualization
# qc.draw(output='text')
# qc.draw(output='mpl')  # if you want a matplotlib visualization

# Convert the most frequent result to decimal
if len(counts) > 0:
    most_frequent_result = max(counts, key=counts.get)
    decimal_result = int(most_frequent_result, 2)
    print(f"Circuit output: {decimal_result} (binary: {most_frequent_result})")
# Out:
# Measurement result: ClassicalRegister(4, 't0')
#
# Measurement results: {'0011': 1024}
# Circuit output: 3 (binary: 0011)
